# %% [markdown]
# # 11/17 17:35~

# %% [markdown]
# # 정적 웹 크롤링과 스크래핑을 이용한 공공데이터와 SNS 데이터 수집

# %%
from bs4 import BeautifulSoup
import urllib.request as req
import io

url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=108"
savename = "C:/Temp/forecast.xml" #xml파일로 저장
req.urlretrieve(url, savename) #urlretrieve()는 받아온것을 파일로 저장하겠다는 함수.

xml = open(savename, "r", encoding="utf-8").read() #read()는 아규먼트 없이 호출하면 모두 읽어라가 된다.
soup = BeautifulSoup(xml, 'xml') # xml #xml문서니까 2번째 argument를 'xml'로 지정한다. 2번째 argument는 Parser를 지정하는 것이다. #xml은 xml파서로, html파일은 html파서로 하는 게 좋다.

info = {}
for location in soup.find_all("location"):
    loc = location.find('city').string #(for문을 이용해 for문에서 생성한)태그 객체를 이용하면 태그객체의 자손 태그에서 찾는다. 여기선 location태그객체의 자손에서  찾는다.
    min_w = location.find_all('tmn')
    max_w = location.find_all('tmx')
    weather = [a.string+"~"+b.string for a, b in zip(min_w, max_w)] #리스트 컴프리헨션. 대괄호 안에다가 식을 준다.

    if not (loc in info):
        info[loc] = []
    for data in weather:
        info[loc].append(data)
print(info)

with open('C:/Temp/forecast.txt', "wt", encoding="utf-8") as f:
    for loc in sorted(info.keys()): #키(도시이름)을 가지고 소팅을 하고 있다.(도시이름을 가나다순으로)
        f.write(str(loc)+'\n') 도시이름을 쓰고 다음 행에다가 리스트 정보를 쓴다.
        for name in info[loc]:
            f.write('\t'+str(name)+'\n') #탭하고 도시마다의 최저,최고온도를 적고 엔터키. (숫자 데이터를 하나를 한 행에 적는다.)
# Out:
# {'서울': ['9~18', '9~18', '7~15', '7~15', '5~13', '5~13', '5~13', '5~13', '4~12', '4~12', '5~11', '4~11', '2~9'], '인천': ['10~17', '10~17', '8~14', '8~14', '6~12', '6~12', '6~12', '6~12', '5~11', '5~11', '6~11', '5~11', '4~9'], '수원': ['8~18', '8~18', '6~16', '6~16', '4~13', '4~13', '5~14', '5~14', '3~12', '3~12', '4~12', '4~11', '1~10'], '파주': ['5~17', '5~17', '3~14', '3~14', '0~13', '0~13', '1~12', '1~12', '1~11', '1~11', '2~11', '0~10', '-2~8'], '이천': ['5~18', '5~18', '3~16', '3~16', '2~14', '2~14', '3~13', '3~13', '1~12', '1~12', '0~12', '0~10', '-1~9'], '평택': ['7~19', '7~19', '5~17', '5~17', '4~16', '4~16', '7~15', '7~15', '4~13', '4~13', '2~13', '3~12', '2~12'], '춘천': ['5~17', '5~17', '4~15', '4~15', '2~13', '2~13', '3~13', '3~13', '2~11', '2~11', '1~11', '1~9', '-1~8'], '원주': ['6~17', '6~17', '5~15', '5~15', '4~14', '4~14', '5~13', '5~13', '2~12', '2~12', '2~12', '2~10', '1~9'], '강릉': ['10~18', '10~18', '10~18', '10~18', '9~14', '9~14', '8~16', '8~16', '7~14', '7~14', '6~14', '7~14', '4~13'], '대전': ['8~19', '8~19', '5~17', '5~17', '5~15', '5~15', '6~15', '6~15', '4~13', '4~13', '2~13', '4~12', '2~11'], '세종': ['7~19', '7~19', '5~17', '5~17', '4~15', '4~15', '6~15', '6~15', '4~12', '4~12', '2~12', '3~12', '1~11'], '홍성': ['7~18', '7~18', '5~16', '5~16', '4~15', '4~15', '6~15', '6~15', '4~12', '4~12', '2~13', '3~12', '2~11'], '청주': ['8~18', '8~18', '6~16', '6~16', '5~14', '5~14', '5~15', '5~15', '4~13', '4~13', '3~13', '4~11', '1~10'], '충주': ['6~18', '6~18', '3~16', '3~16', '4~14', '4~14', '4~14', '4~14', '2~12', '2~12', '1~12', '1~10', '-1~10'], '영동': ['6~18', '6~18', '2~17', '2~17', '3~16', '3~16', '5~15', '5~15', '2~13', '2~13', '1~13', '2~12', '0~14'], '광주': ['10~20', '10~20', '7~19', '7~19', '8~17', '8~17', '7~16', '7~16', '5~14', '5~14', '5~15', '5~13', '4~13'], '목포': ['11~17', '11~17', '9~17', '9~17', '9~15', '9~15', '8~15', '8~15', '8~14', '8~14', '6~14', '8~13', '6~13'], '여수': ['13~18', '13~18', '11~18', '11~18', '11~16', '11~16', '10~16', '10~16', '9~15', '9~15', '8~14', '8~14', '7~13'], '순천': ['9~20', '9~20', '7~20', '7~20', '8~18', '8~18', '9~17', '9~17', '7~17', '7~17', '5~16', '6~15', '4~15'], '광양': ['11~20', '11~20', '8~20', '8~20', '9~18', '9~18', '9~16', '9~16', '6~16', '6~16', '6~16', '7~15', '4~13'], '나주': ['7~20', '7~20', '4~19', '4~19', '5~18', '5~18', '6~17', '6~17', '5~15', '5~15', '3~14', '4~14', '4~15'], '전주': ['8~19', '8~19', '6~18', '6~18', '7~16', '7~16', '6~15', '6~15', '5~14', '5~14', '4~14', '5~13', '3~12'], '군산': ['8~19', '8~19', '6~17', '6~17', '7~15', '7~15', '7~14', '7~14', '5~13', '5~13', '3~14', '5~12', '2~12'], '정읍': ['8~18', '8~18', '6~17', '6~17', '6~15', '6~15', '5~14', '5~14', '4~13', '4~13', '3~14', '4~13', '2~12'], '남원': ['7~19', '7~19', '4~19', '4~19', '5~17', '5~17', '6~16', '6~16', '4~14', '4~14', '2~14', '4~13', '2~13'], '고창': ['8~19', '8~19', '6~18', '6~18', '6~16', '6~16', '6~15', '6~15', '5~13', '5~13', '4~14', '5~13', '2~12'], '무주': ['6~18', '6~18', '3~16', '3~16', '3~16', '3~16', '5~15', '5~15', '2~13', '2~13', '1~13', '2~12', '1~13'], '부산': ['13~20', '13~20', '11~21', '11~21', '11~19', '11~19', '11~18', '11~18', '9~17', '9~17', '8~16', '9~15', '7~15'], '울산': ['11~18', '11~18', '10~19', '10~19', '9~16', '9~16', '9~16', '9~16', '7~16', '7~16', '6~16', '6~15', '4~14'], '창원': ['10~18', '10~18', '9~18', '9~18', '9~17', '9~17', '8~16', '8~16', '7~16', '7~16', '6~15', '6~14', '4~14'], '진주': ['8~19', '8~19', '5~19', '5~19', '5~17', '5~17', '6~17', '6~17', '4~16', '4~16', '2~16', '3~15', '1~14'], '거창': ['5~18', '5~18', '2~18', '2~18', '3~16', '3~16', '3~15', '3~15', '1~14', '1~14', '0~14', '2~13', '-1~13'], '통영': ['12~19', '12~19', '11~20', '11~20', '10~18', '10~18', '9~17', '9~17', '8~16', '8~16', '7~16', '8~15', '6~15'], '대구': ['9~19', '9~19', '7~18', '7~18', '7~16', '7~16', '6~16', '6~16', '5~15', '5~15', '4~15', '4~14', '2~13'], '안동': ['7~17', '7~17', '4~17', '4~17', '4~14', '4~14', '5~15', '5~15', '2~13', '2~13', '1~13', '2~11', '0~11'], '포항': ['11~18', '11~18', '9~19', '9~19',  ...

# %%
import datetime
from bs4 import BeautifulSoup
import urllib.request

now = datetime.datetime.now()
nowDate = now.strftime('%Y년 %m월 %d일 %H시 %M분 입니다.')
print(nowDate)
# 오늘의 날씨
print('[ 오늘의 날씨 요약 ]')
webpage = urllib.request.urlopen('https://search.naver.com/search.naver?sm=top_hty&fbm=0&ie=utf8&query='+urllib.parse.quote_plus('서울날씨')) #https://search.naver.com/search.naver?sm=top_hty&fbm=0&ie=utf8&query=서울날씨 하면 서울날씨가 나온다.
soup = BeautifulSoup(webpage, 'html.parser') #BeautifulSoup 객체를 생성해서 파서를 적용 #심지어 내용을 읽어서 주지 않아도 알아서 BeautifulSoup 객체가 알아서 읽는다.
temp = soup.select('div.temperature_text > strong')
cast = soup.select('span.weather.before_slash')
print(f'--> 서울 날씨 : {temp[0].contents[1]}℃ {cast[0].text}')

webpage = urllib.request.urlopen('https://search.naver.com/search.naver?sm=top_hty&fbm=0&ie=utf8&query='+urllib.parse.quote_plus('광주날씨'))
soup = BeautifulSoup(webpage, 'html.parser')
temp = soup.select('div.temperature_text > strong')
cast = soup.select('span.weather.before_slash')
print(f'--> 광주 날씨 : {temp[0].contents[1]}℃ {cast[0].text}')

webpage = urllib.request.urlopen('https://search.naver.com/search.naver?sm=top_hty&fbm=0&ie=utf8&query='+urllib.parse.quote_plus('제주도날씨'))
soup = BeautifulSoup(webpage, 'html.parser')
temp = soup.select('div.temperature_text > strong')
cast = soup.select('span.weather.before_slash')
print(f'--> 제주도 날씨 : {temp[0].contents[1]}℃ {cast[0].text}')

# %% [markdown]
# ## 11/18 시작

# %%
from bs4 import BeautifulSoup
import urllib.request as req

busNum = '360'
key = '%2BjzsSyNtwmcqxUsGnflvs3rW2oceFvhHR8AFkM3ao%2Fw50hwHXgGyPVutXw04uAXvrkoWgkoScvvhlH7jgD4%2FRQ%3D%3D'
url1 = 'http://ws.bus.go.kr/api/rest/busRouteInfo/getBusRouteList?serviceKey='+key+'&strSrch='+busNum #url을 알고 인증키만 있으면 얼마든지 받아올 수 있다. 그래서 여기서는 정적수집 방법을 쓴다.
res = req.urlopen(url1)

soup = BeautifulSoup(res.read().decode('utf-8'), "xml") #받아온 다음에는 Beautiful Soup으로 원하는 부분을 꺼낸다.

busRouteId = None
for itemList in soup.find_all('itemList') :
    busRouteId = itemList.find('busRouteId').string #360번 버스번호는 외부에 공개된거고 내부적으로는 busRouteId를 가지고 작업한다.
    busRouteNm = itemList.find('busRouteNm').string #외부에 공개된 버스 번호-360번
    if busRouteNm == busNum :
        break

url2 = 'http://ws.bus.go.kr/api/rest/busRouteInfo/getStaionByRoute?ServiceKey='+key+'&busRouteId='+busRouteId
res = req.urlopen(url2)
soup = BeautifulSoup(res.read(), "xml")

busPos = []
for itemList in soup.find_all('itemList') :
    gpsY = itemList.find('gpsY').string
    gpsX = itemList.find('gpsX').string

    busPos.append((gpsY, gpsX))

print('[ ' + busNum + '번 버스의 운행 위치 ]')
if len(busPos) != 0 :
    print(busNum + '번 버스 ' + str(len(busPos)) + '대 운행중...')
    for lat,lng in busPos :
        print(lat+','+lng)
else :
    print('현재 운행중인 ' + busNum + '번 버스가 없어요...') #이 코드를 새벽에 실행하면 돌아다니는 버스가 없기 때문에 추출했을때 아무것도 없다. 이건 실제 운행하고있는 버스번호에 대한 정보이기 때문이다.

print(url1)
print(url2)

# %%
from bs4 import BeautifulSoup
import urllib.request as req

key = '796143536a756e69313134667752417a'
contentType = 'xml'
startIndex = '1'
endIndex = '100'
url = 'http://openapi.seoul.go.kr:8088/'+key+'/'+contentType+'/LampScpgmtb/'+startIndex+'/'+endIndex+'/' #key가 쿼리문자열이 아니라 path의 일부로 들어가게 되어있다.
res = req.urlopen(url)
xml = res.read()
soup = BeautifulSoup(xml, "xml")

pjList = []
for itemList in soup.find_all('row') :
    up_nm = itemList.find('UP_NM').string
    up_nm = '없음' if up_nm is None else up_nm
    pgm_nm = itemList.find('PGM_NM').string
    pgm_nm = '없음' if pgm_nm is None else pgm_nm
    target_nm = itemList.find('TARGET_NM').string
    target_nm = '없음' if target_nm is None else target_nm
    u_price = itemList.find('U_PRICE').string #강습료
    u_price = '없음' if u_price is None else u_price
    pjList.append((up_nm, pgm_nm, target_nm, u_price))

print('[ 서울 청소년 수련관 강좌 리스트 ]')
for up_nm,pgm_nm,target_nm,u_price in pjList :
    print(up_nm+','+pgm_nm+','+target_nm+','+str(u_price))

# %%
from bs4 import BeautifulSoup
import urllib.request as req
import io

#R에서는 다루지 않았던 것이라고 함.
#서울에서 관리하는 지하철인 1~4호선만 각 호선 역마다의 탑승자수를 제공한다. 각 역마다 얼마만큼의 승객들이 이용하고 있는지를 파악할 수 있다.

key = '796143536a756e69313134667752417a'
contentType = 'xml'
startIndex = '1'
endIndex = '100' #100개만 가져온다. #1000까지만 받아들이고 607개까지 받아온다. 1000개를 넘어서 요청하면 아예 안 준다.
date = '20221114' #모든 데이터에 대해서 최신화를 해놓지는 않는다. 3일은 지나야 한다고 함.

url = 'http://openapi.seoul.go.kr:8088/'+key+'/'+contentType+'/CardSubwayStatsNew/'+startIndex+'/'+endIndex+'/'+date+'/' #들어가면 WORK_DT라고 집계일도 나와있다.
print(url)
res = req.urlopen(url)
xml = res.read()

soup = BeautifulSoup(xml, "xml")

subwayList = []
for itemList in soup.find_all('row') :
    line_num = itemList.find('LINE_NUM').string
    sub_sta_nm = itemList.find('SUB_STA_NM').string
    ride_pasgr_num = itemList.find('RIDE_PASGR_NUM').string
    alight_pasgr_num = itemList.find('ALIGHT_PASGR_NUM').string
    subwayList.append((line_num, sub_sta_nm, ride_pasgr_num, alight_pasgr_num)) #이 정보들을 튜프로 만들어서 리스트에 append한다. 그럼 이건 튜플리스트가 된다. 엘리먼트들이 튜플인 리스트.

print('[ 서울시 지하철호선별 역별 승하차 인원 정보 ]')
for line_num, sub_sta_nm, ride_pasgr_num, alight_pasgr_num in subwayList :
    print(line_num+','+sub_sta_nm+','+ride_pasgr_num+','+alight_pasgr_num) #튜플로 저장되어있는 애들을 언패킹해서 각각 출력한다.
# Out:
# http://openapi.seoul.go.kr:8088/796143536a756e69313134667752417a/xml/CardSubwayStatsNew/1/100/20221114/
# [ 서울시 지하철호선별 역별 승하차 인원 정보 ]
# 1호선,서울역,52325,49644
# 1호선,시청,25719,25978
# 1호선,종각,38814,38378
# 1호선,종로3가,26061,23616
# 1호선,종로5가,23643,23334
# 1호선,동대문,11053,10623
# 1호선,신설동,14285,14019
# 1호선,제기동,17780,18303
# 1호선,청량리(서울시립대입구),20419,20162
# 1호선,동묘앞,8246,8501
# 2호선,시청,25383,24800
# 2호선,을지로입구,46082,47359
# 2호선,을지로3가,25072,25213
# 2호선,을지로4가,14557,14744
# 2호선,동대문역사문화공원(DDP),13096,14938
# 2호선,신당,14264,14732
# 2호선,상왕십리,14883,14526
# 2호선,왕십리(성동구청),16595,13959
# 2호선,한양대,14801,16565
# 2호선,뚝섬,22402,23994
# 2호선,성수,39448,42587
# 2호선,건대입구,35181,37162
# 2호선,구의(광진구청),24844,24672
# 2호선,강변(동서울터미널),31834,30442
# 2호선,잠실나루,16735,16360
# 2호선,잠실(송파구청),72559,72952
# 2호선,잠실새내,22669,22245
# 2호선,종합운동장,8400,9525
# 2호선,삼성(무역센터),52310,52686
# 2호선,선릉,61520,55025
# 2호선,역삼,57526,64910
# 2호선,강남,80945,77622
# 2호선,교대(법원.검찰청),35790,40478
# 2호선,서초,23016,22153
# 2호선,방배,19756,20604
# 2호선,사당,38702,42820
# 2호선,낙성대(강감찬),28344,28464
# 2호선,서울대입구(관악구청),48545,47916
# 2호선,봉천,24998,23718
# 2호선,신림,58253,56003
# 2호선,신대방,26559,25862
# 2호선,구로디지털단지,62547,62603
# 2호선,대림(구로구청),25528,25770
# 2호선,신도림,48816,47909
# 2호선,문래,22868,23487
# 2호선,영등포구청,23476,24187
# 2호선,당산,19425,23241
# 2호선,합정,30333,32413
# 2호선,홍대입구,57414,60199
# 2호선,신촌,36880,37301
# 2호선,이대,18014,20106
# 2호선,아현,11043,10747
# 2호선,충정로(경기대입구),10870,11444
# 2호선,용답,3257,3483
# 2호선,신답,1755,1988
# 2호선,신설동,3486,3383
# 2호선,도림천,1410,1477
# 2호선,양천구청,7579,7841
# 2호선,신정네거리,11028,11250
# 2호선,용두(동대문구청),2546,2558
# 3호선,지축,6471,6278
# 3호선,구파발,22321,21205
# 3호선,연신내,36864,35063
# 3호선,불광,16853,17576
# 3호선,녹번,16753,15351
# 3호선,홍제,18939,18209
# 3호선,무악재,4303,4356
# 3호선,독립문,7254,7471
# 3호선,경복궁(정부서울청사),24565,25405
# 3호선,안국,25421,25791
# 3호선,종로3가,10367,11915
# 3호선,을지로3가,11852,11660
# 3호선,충무로,2,0
# 3호선,동대입구,11013,12588
# 3호선,약수,13356,13082
# 3호선,금호,8333,7802
# 3호선,옥수,9223,9407
# 3호선,압구정,33354,36294
# 3호선,신사,28801,29687
# 3호선,잠원,5266,5039
# 3호선,고속터미널,37672,36302
# 3호선,교대(법원.검찰청),16006,10768
# 3호선,남부터미널(예술의전당),29845,30927
# 3호선,양재(서초구청),39836,43422
# 3호선,매봉,13433,12984
# 3호선,도곡,5588,5347
# 3호선,대치,11817,11846
# 3호선,학여울,2012,2021
# 3호선,대청,11079,10446
# 3호선,일원,11696,11394
# 3호선,수서,18474,19031
# 3호선,가락시장,9595,9512
# 3호선,경찰병원,8094,8070
# 3호선,오금,6946,6105
# 4호선,당고개,9608,8410
# 4호선,상계,19827,18504
# 4호선,노원,18966,21578
# 4호선,창동,26152,27504
# 4호선,쌍문,30025,28354
# 4호선,수유(강북구청),35006,35407

# %%
import urllib.request
import json #json을 이용할거라면 필요

client_key = 'izGsqP2exeThwwEUVU3x' #https://developers.naver.com/docs/serviceapi/search/blog/blog.md#%EB%B8%94%EB%A1%9C%EA%B7%B8 에서 key와 secret이 뭔지 확인
client_secret = 'WrwbQ1l6ZI' #secret이 뭔지 강사도 정확히 모른다고 한다. R시간에 구글에 "네이버 오픈 api" 검색해서 맨 위에 사이트 들어간 다음 key와 secret을 발급받는 것 같다.
query = '스마트폰'
encText = urllib.parse.quote_plus(query)
num = 100
naver_url = 'https://openapi.naver.com/v1/search/blog.json?query=' + encText + '&display=' + str(num)#html이나 xml이면 BeautifulSoup을 쓰지만 json이면 간단해서 쓰지 않았다.

request = urllib.request.Request(naver_url) #Request()를 이용해 Request객체를 생성해서 add_header를 통해 네이버가 제공한 access key를 걔네가 정해준 이름으로 넣는게 필요하다.
request.add_header("X-Naver-Client-Id",client_key)
request.add_header("X-Naver-Client-Secret",client_secret) #요청 헤더에다가 인증 키 등의 정보를 담아야 한다. http프로토콜은 헤더가 바디가 있다. 헤더에 담아서 보낸다. add_header()를 실행시키는 순서는 상관이 없다.
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode == 200):
    response_body = response.read()
    dataList = json.loads(response_body) #BeautifulSoup을 쓸 필요없이 json.loads()만 해주면 된다. 그럼 함수가 응답된 내용을 가지고 딕셔너리로 리턴해준다. key:value 쌍으로 되어있는 데이터를 꺼내서 처리하면 되는 거다.

    print('[' + query + '에 대한 네이버 블로그 글 ]')
    for count, data in enumerate(dataList['items'], 1) :
        print (str(count) + ' : ' + data['title'])
        print ('[' + data['description'] + ']')
else:
    print('오류 코드 : ' + rescode)
# Out:
# [스마트폰에 대한 네이버 블로그 글 ]
# 1 : <b>스마트폰</b> 속도가 2배로 빨라져서 속이 뻥 뚫리는 방법
# [<b>스마트폰</b> 속도가 2배로 빨라져서 속이 뻥 뚫리는 방법 <b>스마트폰</b> 속도가 느려져서 휴대폰을 바꿔야 하나 하는 생각을 해본적이 있나요? 그렇다면 오늘 포스팅 읽고 10초안에 해결이 가능할 것 같습니다~ 뭘... ]
# 2 : LTE <b>스마트폰</b>, 삼성 갤럭시 A23 간단 후기
# [오늘 저와 함께 살펴볼 제품은 LTE <b>스마트폰</b>, 삼성 갤럭시 A23입니다. 이 제품은 제가 지난 6월 중순에... 이 제품은 퀄컴의 스냅드래곤 680을 프로세서로 사용하는 전형적인 보급형 <b>스마트폰</b>인데요. LPDDR4X... ]
# 3 : <b>스마트폰</b> 부업으로 매달 수익 내는 중
# [남자, 여자 할 것 없이 누구나 할 수 있는 <b>스마트폰</b> 부업이 인기를 끌고 있는데요 <b>스마트폰</b>으로 할 수 있는 부업 종류는 여러 가지가 있지만 그중 가장 쉽게 진행하면서 매달 안정적인 수익을 낼 수 있는 것은... ]
# 4 : <b>스마트폰</b>마이크 소형마이크 난 이거
# [<b>스마트폰</b>마이크 소형마이크 난 이거 선택 아이와 영상 촬영을 자주 하다 보니 소형 마이크의 필요성을... <b>스마트폰</b>으로 연결이 되니 화면을 녹화하고 마스크를 착용하고 사용하고 있습니다. 마이크를 들지 않고... ]
# 5 : 내 집 도어락 <b>스마트폰</b> 이나 카드로 여는법 (1분이면 끝)
# [오늘의 꿀팁 요즘 집에 열쇠키가 아닌 스마트 도어락으로 되어서 비번을 누르고 문을 열게 설정이... 오늘은 이런거 필요 없이 한방에 손쉽게 내 <b>스마트폰</b>이나 카드로 여는 방법을 알려드릴꺼에요. 내 집이나... ]
# 6 : 삼각대 <b>스마트폰</b> 홀더 세도나 안정적인 마운트
# [우리는 일상생활에서 카메라, <b>스마트폰</b> 삼각대를 사용할 때 쓰이는 홀더에 관하여 이야기하려고... 박스를 열어보았을 때 구성품은 삼각대 <b>스마트폰</b> 홀더 하나였어요. 단순히 보조 역할만 할 것 같았지만 높은... ]
# 7 : 내PC돌보미 국가에서 지원하는 PC, <b>스마트폰</b> 해킹 무료 보안점검
# [물론 이번 사고는 해킹과는 상관없었지만 기업, 개인들의 PC 나 <b>스마트폰</b> 해킹으로 인한 크고 작은... PC 뿐만 아니라 <b>스마트폰</b>도 마찬가지죠? 그나마 아이폰은 보안이 철저해서 좀 덜하다고 하지만 여전히 해킹... ]
# 8 : ipTIME C타입허브 맥북허브 <b>스마트폰</b>에 연결해봤어요
# [아이피타임허브를 <b>스마트폰</b>과 연결한 후 마우스와도 연결하였는데요 그러면 폰 화면속에 화살표커서가 나타나는데 기본적으로 작은 검은색이라 잘 안보이기도 합니다 크기설정을 어디서 하는지는... ]
# 9 : 아이 <b>스마트폰</b> 영상 노출에 대한 고민
# [아이 <b>스마트폰</b> 영상 노출에 대한 고민고민 안보여주는게 좋다는 건 알고 있지만 알고 있어도 어쩔 수 없이 보여줄 수밖에 없다면 ? 엄빠라면 아이 <b>스마트폰</b> 영상 노출에 대한 고민 많이들 하실 거 같애,,, 나도... ]
# 10 : 포코 X4 GT 스펙분석, 최고의 LCD <b>스마트폰</b>
# [많었던 <b>스마트폰</b>입니다. X3 GT의 후속 모델인 X4 GT는 X3보다 훨씬 뛰어난 성능과 144Hz 주사율로... 돌비비전을 지원한다는점도 특징인데, 이는 샤오미가 LCD <b>스마트폰</b>의 화질과 완성도에도 어느정도 관심을... ]
# 11 : <b>스마트폰</b>짐벌 셀카봉삼각대 추천 후기
# [그래서 <b>스마트폰</b>짐벌기능을 가지고 있는 셀카봉삼각대에 눈길이 갔습니다 모자 나노 SE 스마트본 짐벌 셀카봉 색상은 블랙과 민트 2가지가 있는데 전 민트색상을 개인적으로 좋아해서 민트색상으로... ]
# 12 : <b>스마트폰</b>어플개발,어렵지않아요!
# [보시는 것처럼 스마트메이커는 가상의 <b>스마트폰</b> 화면에 원하는 기능이나 창을 드래그 앤 드롭 하는 것만으로도 어플을 만들 수 있습니다. 정말 쉬워 보이죠? 스마트메이커의 사용법은 2시간 무료 동영상만 따라... ]
# 13 : <b>스마트폰</b> 중독 문제점과 아날로그 감성의 필요성
# [<b>스마트폰</b> 중독은 이제 중독이라고 부르기도 민망할 정도로 엄청난 파급력으로 생활 전반을 지배하고... © the_average_tech_guy, 출처 Unsplash 카카오톡 문제는 일단락 되었지만 <b>스마트폰</b>이 우리 일상생활에서... ]
# 14 : 충전기 없이 <b>스마트폰</b> 배터리 충전 방법과 배터리 85% 충전 설정
# [충전기 없이 <b>스마트폰</b> 배터리 충전 방법과 배터리 85% 충전 설정 요즘 <b>스마트폰</b> 없이 외출하려면 왠지 불안한 생각마저 듭니다. 왜냐하면 <b>스마트폰</b> 안에는 은행관련 카드, 주민등록증, 면허증, 교통카드 등등... ]
# 15 : 갤럭시 보급형 <b>스마트폰</b> A52S A53 A73 자급제 가격...
# [갤럭시 보급형 <b>스마트폰</b> 3형제 A52S A53 A73 자급제폰 가격 대비 성능비교하니 A52S가 레전드로 남은... LG가 <b>스마트폰</b> 사업을 포기하면서 합리적인 가격의 쓸만한 보급형 <b>스마트폰</b>을 찾기가 더... ]
# 16 : [유진쌤의 조금은 고지식한 이야기] <b>스마트폰</b>, 언제 사줘야 할까?
# [알아보니 공신폰(<b>스마트폰</b>과 똑 닮았지만 인터넷이 차단된 폰)은 오히려 요금제 같은 것들을 포함하면... 게다가 요즘은 학교마다 태블릿과 같은 스마트 기기들이 잘 구비되어 있기 때문에 <b>스마트폰</b>이 없다고... ]
# 17 : 삼성 갤럭시 와이드6 가성비 5G <b>스마트폰</b>, 추천 사용자는?
# [삼성 <b>스마트폰</b> 가성비 라인업인 Galaxy Wide 시리즈의 신작 갤럭시 와이드6 (SM-A136SB)가 출시되었습니다. 대화면과 대용량 배터리, 쿼드 카메라를 탑재한 5G <b>스마트폰</b>이고요. 전작과 마찬가지로 SK텔레콤 단독... ]
# 18 : 카카오톡 메신저 쉽게 가입하기, <b>스마트폰</b>강사 김미경 교육
# [SNS <b>스마트폰</b>강사 김미경 인사드려요. 추석연휴 잘 보내고 계시지요. 카카오톡으로도 명절 추석인사... 하지만 노인복지관, 경로당, 평생학습관 등 <b>스마트폰</b>활용교육 하다보면 카카오톡 가입 안되신 분들이 1~2분... ]
# 19 : <b>스마트폰</b> 속으로 쏙 들어온 ‘모바일 운전면허증’ 발급 후기
# [<b>스마트폰</b> 속으로 쏙 들어온 운전면허증, 모바일 운전면허증을 발급받아 사용해 봤어요. 2022년 7월 28일부터 <b>스마트폰</b>의 운전면허증을 신분확인 용도로 발급받아 사용할 수 있게 되었다는 소식 들으셨죠? 사실... ]
# 20 : [모닝 어반] <b>스마트폰</b> 거치대 설치
# [가장 먼저 할 튜닝은 <b>스마트폰</b> 거치대 작업입니다. 저는 가장 기본형인 컴팩트 오디오 장착 모델을 선택했기 때문에 차에 내비게이션이 없어서 <b>스마트폰</b> 앱을 써야 합니다. 모닝 동호회에서 많은 분들이... ]
# 21 : 꼭! 알아두자. 중고 <b>스마트폰</b> 구입 시 주의사항!
# [최근 <b>스마트폰</b>은 전 세계적으로 거의 보편화되었으며, 삼성 갤럭시 폴드4, 아이폰14 PRO 등 프리미엄 <b>스마트폰</b>들은 1년을 주기로 출시되고 있는데요. 하지만 소비자의 기대를 만족시키기 위해 최신... ]
# 22 : 자녀 <b>스마트폰</b> 관리 어플로 한 후기
# [등을 <b>스마트폰</b>을 통해서 접하기 때문입니다. 단순 전화 기능만 가능한 스마트 기기를 쓰게 된다면 친구들에게 따돌림을 당할 수도 있고 아이들이 접해야 하는 세상 속 창구를 막아 버릴 가능성도 있습니다.... ]
# 23 : 귀뚜라미 보일러 <b>스마트폰</b> 사용방법 및 IOT 설치하기
# [#귀뚜라미 #보일러조절기 #보일러원격제어 #보일러<b>스마트폰</b> #IOT보일러 #거꾸로NEW콘덴싱 #귀뚜라미<b>스마트폰</b>사용방법 #귀뚜라미<b>스마트폰</b>설치방법 #귀뚜라미보일러 #방온도조절 #스마트보일러 #스마트조절기... ]
# 24 : 광주휴대폰복구 <b>스마트폰</b> 작동이 안되나요
# [맡아둔 <b>스마트폰</b>을 뒷주머니에 넣어놓고 깜빡하고 물에 들어갔다가 심지어 떨어트리고 파손까지 시키니까 성질이 확 올라오더라고요. 정말 제가 짜증 제대로 낼 뻔했는데 광주데이터복구에서 <b>스마트폰</b>복구... ]
# 25 : <b>스마트폰</b> 짐벌 dji 오즈모모바일 6 발빠른 사용 후기
# [사용했음에도 <b>스마트폰</b> 짐벌 라인은 처음이였던 나에게 이 기계는 어떻게 다가왔을까? 글 / 사진 / 영상 Ben Moon 심플한 제품구성, 가벼운 무게로 <b>스마트폰</b> 짐벌 편의성 높여 제품 박스는 요렇게 화이트... ]
# 26 : <b>스마트폰</b> 터치 등산장갑 착용후기
# [바로 <b>스마트폰</b> 터치가 가능한 등산장갑이라 여러분들께 한번 소개를 해볼까해요 구입한지는 반년이... 단연 <b>스마트폰</b>의 터치 유무였을 거에요 아무래도 한번 착용을 하면 꼈다 뺐다 하는 것이 불편하게 느껴질수... ]
# 27 : 갤럭시 <b>스마트폰</b> 배터리 수명 및 오래 사용할 수 있게...
# [갤럭시 <b>스마트폰</b> 배터리 수명 및 오래 사용할 수 있게 관리하는 법~ 갤럭시 배터리 수명이 다하면 <b>스마트폰</b>을 교체를 해야 하는 일이 발생하기 때문에~ <b>스마트폰</b> 배터리 관리하는 법을 잘 알아야 합니다.... ]
# 28 : 추억의<b>스마트폰</b> LG G3, 삼성 갤럭시 A8
# [지금은 사라져버린 LG <b>스마트폰</b>. 한때는 톡톡튀는 기능과 디자인으로 많은 사랑을 받았던 그 핸드폰. 처음이자 마지막으로 사용했던 LG <b>스마트폰</b> G3. 그리고 그 다음 사용하게된 삼성 갤럭시 A8. 두 <b>스마트폰</b>모두... ]
# 29 : IT학원 <b>스마트폰</b>으로도 가능한 영상편집 배워봤어요!
# [프리미어 영상편집 , 유튜브 크리에이팅 영상편집, <b>스마트폰</b>을 이용한 생활영상제작, 에프터이펙트... 제가 수강한 과정은 <b>스마트폰</b>을 이용한 생활영상제작이에요~ 제대로 된 카메라가 있는 것은 아니고 또... ]
# 30 : 유튜브 촬영장비 3만원 대 아이폰 8핀 <b>스마트폰</b> 무선마이크...
# [다만 한가지 아쉬운점이 있다면, 아이폰은 8핀이라 일반 <b>스마트폰</b> 마이크는 장착할 수 없다는 점. 저는... 싶은데, <b>스마트폰</b>과 거리가 멀어서 음성 녹음이 잘 안 될 때가 있어요. 뷰맛집 캠핑장에서 멍 때리기... ]
# 31 : [BP/IT] 손목이 아플 때 태블릿, <b>스마트폰</b> 스탠드
# [BP's : 최근에 태블릿, <b>스마트폰</b> 스탠드(거치대)를 몇 개 구입했는데 그 이유는 <b>스마트폰</b>이 무거운데 계속 손으로 들고 있다보니 팔목과 어께에 무리가 가는 것을 느꼈기 때문이다. 알리익스프레스나 쿠팡, 네이버... ]
# 32 : 강제 디지털 디톡스, <b>스마트폰</b> 액정이 고장 나버린 하루
# [새 <b>스마트폰</b>을 주문하는 과정에서 인증을 해야 하는데 액정 나간 폰으로 뭘 하겠어요 (•̥̥̥⌓•̥̥̥) 다행히 유심을 다른 폰으로 옮겨서 간단하게 해결되긴 했습니다 강적은 바로 데이터 옮기기. 폰 자체가... ]
# 33 : 라이카 M렌즈 교체형 <b>스마트폰</b> 샤오미 12S 울트라
# [단순한 브랜드 협업 이외에도 꽤 재미있는 <b>스마트폰</b>을 준비하고 있다는 것이 공개되어 화제입니다.... 물론 양산 버전은 아니지만 렌즈교체형 <b>스마트폰</b> 카메라의 가능성을 보여준 것만으로도 상당히 의미... ]
# 34 : UXUI 디자이너의 컴퓨터, 노트북, 탭, <b>스마트폰</b>
# [<b>스마트폰</b> 다수의 종을 사용합니다. © stux, 출처 Pixabay 데스크탑 조립용 데스크탑과 삼성 모니터를... <b>스마트폰</b> 그리고 다양한 <b>스마트폰</b>이 있으며 종류는 대략 5종... 확인 용입니다. 아이폰 13, 아이폰 6, 갤럭시... ]
# 35 : 아이폰 갤럭시 <b>스마트폰</b> 미러링 프로그램 심플한 Vysor
# [<b>스마트폰</b> 화면 미러링 프로그램은 검색을 통해 다양한 종류를 볼 수 있지만 무료는 생각보다 많지... 오늘은 아이폰, 갤럭시 등에서 사용할 수 있는 <b>스마트폰</b> 무료 미러링 프로그램 Vysor에 대해 알아보도록... ]
# 36 : [서초구 양성평등활동센터] 이제 나도 <b>스마트폰</b> 영상 제작자!
# [나도 <b>스마트폰</b> 영상 제작가’ 프로그램에 참여했습니다. 11월10일~11일 양일간 오후 2시~5시까지 서초여성가족플라자 잠원센터에서 열렸는데요. <b>스마트폰</b> 영상제작 이론과 실습이 있었어요. 서초구... ]
# 37 : 차량용 <b>스마트폰</b> 거치대 스마트키 폴딩키 딱이에요!
# [저 외에도 차 키 또는 <b>스마트폰</b>을 깜빡하고 외출하시는 분들이 많은가 봐요^^ 그리고 폴딩키나 스마트키 기판을 옮겨 사용하는 DIY용 케이스 톡이기 때문에 배터리와 PCB 기판을 분해할 때 손상되지 않게 해야... ]
# 38 : 갤럭시a13 가격 0원 요금도 저렴한 보급형 <b>스마트폰</b>
# [월마다 내는 <b>스마트폰</b> 할부금이나 통신 요금도 가계 생활비 지출에 큰 몫을 차지하고 있습니다. 게다가 갤럭시S 시리즈나 갤럭시 폴더블 시리즈, 아이폰 시리즈 등 프리미엄 최신 <b>스마트폰</b>이라고 할부금, 통신... ]
# 39 : <b>스마트폰</b> 리폼? 갤럭시S20 FE 후면 커버 셀프로 교체
# [비주입니다...^^ 세상에나 이 <b>스마트폰</b>이 둘째가 가지고 다니는 거에요. 도대체 어떻게 가지고 다니길래... 둘째가 가지고 다니는 <b>스마트폰</b>이 갤럭시S20 FE 모델인데요. 저는 여태까지 뒷면이 유리로 되어 있는지... ]
# 40 : 솔잠 스마트 카본매트 좌우분리와 <b>스마트폰</b> 연동 후기!
# [<b>스마트폰</b>에 솔잠 스마트앱을 설치하고 어플을 연상태로 조절기 전원을 켜고 S버튼을 누르면 핸드폰에서 연결가능한 디바이스를 검색해서 블루투스 연결이 됩니다^0^ <b>스마트폰</b>에서 좌우 온도 좌우 타이머를... ]
# 41 : 당신만 모르는 <b>스마트폰</b> 갤러리 앱 활용 5가지 꿀팁
# [당신만 모르는 <b>스마트폰</b> 갤러리 앱 활용 5가지 꿀팁 갤럭시 <b>스마트폰</b> 갤러리에는 카메라 앱은 물론 휴대폰에 설치된 어플을 통해 생성되는 많은 사진과 영상들이 존재합니다. 하지만! 늘 찍고 보관만 하고 있으면... ]
# 42 : 우리 아이, <b>스마트폰</b>을 손에서 놓지 않는다면 &apos;이것&apos; 조심하세요!
# [급성 후천성 일치 내사시는 10년 전까지는 드문 질환이었지만, 최근 코로나19로 인해 스마트기기를 이용한 학습이 늘면서 청소년기의 아이들에게 발생이 늘었습니다. <b>스마트폰</b>을 30cm이내로 1시간 이상 지속하여... ]
# 43 : 세도나 <b>스마트폰</b> 홀더 거치대 SSH-360 사용 후기, 흥미롭다.
# [세도나 <b>스마트폰</b> 홀더 거치대 SSH-360에 대해 이야기해 보겠습니다. 미리 언급하지만, 업체로부터 제품을 제공 받았습니다. 휴대폰을 활용해서 유튜브 또는 인스타그램을 촬영하는 분들은 이런 <b>스마트폰</b>... ]
# 44 : 오즈모모바일6 핸드폰 <b>스마트폰</b>짐벌 추천
# [추가되어서 <b>스마트폰</b>짐벌로 추천 소개합니다 오즈모모바일6 핸드폰짐벌 구성품으로 짐벌 본체, 세워서 영상을 찍을 수 있는 삼각대, <b>스마트폰</b> 케이스에 부착하는 클램프, 보관용 파우치, 충전 케이블이... ]
# 45 : 벤로코리아 BK10 <b>스마트폰</b> 삼각대 셀카봉 추천
# [<b>스마트폰</b> 삼각대 추천 셀카봉 추천 저는 워낙 운동영상도 매번 찍고 유튜브 영상도 찍어서 <b>스마트폰</b> 삼각대 종류별로 많이 사용했거든요 저가도 사용해보고 고가도 사용해봤는데 이번에 사용한 벤로코리아... ]
# 46 : <b>스마트폰</b> 카메라 대용량 보조배터리
# [것이 <b>스마트폰</b>을 가지고 다니는 중에 배터리가 없을 때에 당황스럽고 카메라 촬영 중에도 배터리가... 저 같은 사람에게 정말 딱이라고 생각이 되는 제품 100%에서 충전을 시작하고 <b>스마트폰</b> 카메라 등을... ]
# 47 : Type C <b>스마트폰</b>, PC나 TV화면에 출력하기
# [이 컨버터를 사용하면 충전 단자가 Type C인 최신 <b>스마트폰</b>이나 애플 노트북과 같은 맥북을 커다란... 그러면 이제 이 컨버터를 이용해 <b>스마트폰</b>을 TV에 연결해 틀어보겠습니다. 별도의 HDMI 케이블... ]
# 48 : [교내 활동] <b>스마트폰</b> 사용 줄이기 캠페인 구상
# [위한 <b>스마트폰</b> 다이어트 프로그램운영이 있다(<b>스마트폰</b> 다이어트라니!). 담임교사일 때 경험해본... 또 슬러지·큐레이션·스마트 공개·맞춤형 기본 설정 등 새롭게 등장한 선택 설계 아이디어들을 소개하고... ]
# 49 : 삼성 <b>스마트폰</b> 갤럭시 공장 초기화 방법 1분만에 해결
# [<b>스마트폰</b>을 사용하면서 초기화가 필요한 순간이 종종 있습니다. 새로운 단말기를 구매해 기존 <b>스마트폰</b>을 중고로 판매하는 순간이나 사용하면서 너무 느려졌다고 느껴진다면 포맷을 통해 다시 빠릿한 느낌을... ]
# 50 : <b>스마트폰</b>MMORPG 카오스포털 CBT 일정 및 이벤트 소식
# [지난번에 <b>스마트폰</b>MMORPG 신작 카오스포털에 대해서 소개 드린 적이 있습니다. 거대한 포털을 타고... 단순히 혼자서만 성장하는 <b>스마트폰</b>MMORPG가 아니라 강해지는 루트가 다양하다고 할 수 있겠습니다.... ]
# 51 : <b>스마트폰</b> 밸류체인 (아이폰 &amp; 갤럭시 비교)
# [자화전자, 덕우전자, 비에이치 등 공부하기 전에 <b>스마트폰</b> 밸류체인 다시 한 번 복습 오래간만에 텔레그램 자료실에 올려 둔 자료를 꺼내옴 현재 <b>스마트폰</b> 비지니스쪽이 전반적으로 슬로우한 상황 아마... ]
# 52 : <b>스마트폰</b> sd 메모리 카드 인식 불량 저장장치 복구
# [요즘은 보통 <b>스마트폰</b> 사용할 때 SD 메모리 카드가 들어가는 걸 사용하지는 않는거 같아요 하지만 저는... 부득이하게 <b>스마트폰</b>을 바꿔야하는 일이 있으면 되도록 SD 메모리 카드가 들어갈 수 있는 모델을... ]
# 53 : 안드로이드 <b>스마트폰</b> 스캔 어플 브이플랫 vFlat
# [<b>스마트폰</b>으로 할 수 있는 일이 참 많죠? 그중에서 오늘은 안드로이드 스캔 어플 알려드릴게요 편리하고 간단하게 <b>스마트폰</b> 스캔 가능한 브이플랫 vFlat 앱 예전에는 스캔 한번 하려면 스캐너가 있어야 했고 또... ]
# 54 : 긴급상황 시! <b>스마트폰</b> SOS 메시지 보내기로 위기탈출~
# [<b>스마트폰</b> SOS 메시지 보내기로 위기탈출~ 세상살이 힘들고 위급할 때 있는 거 맞죠? 어떤 상황에서... 위와 같은 설정이 완성되면 비로소 스마트으로 SOS 메시지 보내기가 시작됩니다. 만약에 경찰 112에... ]
# 55 : [서평이벤트(~22일)] <b>스마트폰</b> 10분만요 / 조윤주 / 인성동화...
# [서평단 모집 <b>스마트폰</b> 10분만요 날아라 꼬꼬 할머니 인성동화 어린이 &gt; 국내창작동화 발행일 2022년 11월... 이번에는 하루 종일 <b>스마트폰</b> 게임을 하고 싶어 하는 아이에게 출동했다! 가족들과 함께하는 외식... ]
# 56 : <b>스마트폰</b> 때문에 헤어지는 경우?
# [<b>스마트폰</b>은 현대인의 필수품이죠. 24시간 몸에 붙어있다고 해도 과언이 아닙니다. 물론 사랑하는 연인과 연락하게 해주는 고마운 도구이기도 하지만 사실 이 <b>스마트폰</b> 때문에 싸우고, 연애가 깨지는 경우도 적지... ]
# 57 : 리버티샵 유튜브 <b>스마트폰</b> 삼각대 (카메라 거치대 추천)
# [오늘의 포스팅 #리버트샵 #유튜브<b>스마트폰</b>삼각대 #삼각대 입니다. 평소 가족사진을 찍거나 혼자 블로그 포스팅할 제품을 촬영할 때 자주 사용하는 #<b>스마트폰</b>삼각대 얼마전 기존 삼각대가 부숴져서 새로운... ]
# 58 : 아이폰도 편리한 <b>스마트폰</b>무선마이크 COMS 소형마이크
# [아이폰도 사용하기 편리한 COMS <b>스마트폰</b>무선마이크 요리할때 종종 동영상도 찍어보기 때문에 나름... COMS <b>스마트폰</b> 소형마이크입니다 구성도 심플해요 마이크 수신부와 송신부 그리고 8핀젠더와 충전용USB 끝!... ]
# 59 : 삼각대셀카봉 <b>스마트폰</b>짐벌 기능까지 한번에~MOZA NANO SE
# [#<b>스마트폰</b>셀카봉 #<b>스마트폰</b>삼각대 #삼각대셀카봉 #<b>스마트폰</b>짐벌 #MOZANANOSE #사진촬영 #사진잘찍는법 #수평맞추기 사진을 찍으면서 잘 찍고 싶은 마음은 누구나 같다. 사진을 잘 찍는다는 것은 쉽지 않은 일이지만... ]
# 60 : 2022년 청소년 <b>스마트폰</b> 가족치유캠프에서 힐링하고 가요!
# [요즘 정보화로 인해서 <b>스마트폰</b> 없는 청소년들은 찾아보기 힘들거라고 생각해요. 그래서 인지 <b>스마트폰</b> 중독까지 와서 화면으로 들어갈 정도로 <b>스마트폰</b>을 사용하는 청소년들이 많아졌어요. <b>스마트폰</b>... ]
# 61 : 페어폰 벤치마킹? 노키아가 내놓은 착한 <b>스마트폰</b>
# [보급형 <b>스마트폰</b> X30 5G를 선보였다고 전했다. HMD 글로벌은 이전 노키아 직원들이 설립한 회사다. 지난 2016년 노키아 <b>스마트폰</b> 사업부를 일부 인수했다. 이후부터 노키아 이름을 단 저가 <b>스마트폰</b>을... ]
# 62 : <b>스마트폰</b>이 바꾸고 있는 우크라이나 전쟁
# [‘<b>스마트폰</b>’을 활용한 국민 참여는 생각보다 전쟁 지원에 많은 도움이 되는 것으로 보인다. 지난 3월... 우크라이나 국민들은 전쟁 상황을 <b>스마트폰</b>으로 촬영해 러시아의 침공을 세계에 알리는 큰 역할을... ]
# 63 : 삼성 갤럭시 <b>스마트폰</b>, 크롬 모바일 앱 다크모드 설정 방법
# [삼성 갤럭시 <b>스마트폰</b>과 크롬 모바일 앱의 다크모드 적용 방법을 보여드릴게요. 눈의 피로를 줄여줄 수 있을 뿐 아니라, OLED 패널을 탑재한 <b>스마트폰</b>을 사용하고 있다면 다크모드 적용만으로 배터리 소모를... ]
# 64 : usb없이 <b>스마트폰</b> 데이터(사진,동영상) pc로 옮기기 (삼성...
# [안녕하세요 <b>스마트폰</b>에있는 사진이나 동영상등을 옮길때 다들 어떻게하시나요? 생각보다 회사 사업계획서나 포스팅이나 레포트를 할때 <b>스마트폰</b>에 있는 데이터를 예전에는 삼성... ]
# 65 : 윈도우 스티커메모 <b>스마트폰</b> 원노트와 동기화 해두세요
# [텐데요, <b>스마트폰</b>에 원노트 앱 설치 후 동기화하면 윈도우 스티커 메모를 더 유용하게 활용할 수... 다음으로 <b>스마트폰</b> 앱스토어, 플레이스토어로 이동해서 Microsoft OneNote를 검색하고 설치합니다. 설치가... ]
# 66 : 인스타그램 <b>스마트폰</b> 앱, PC 버전 로그아웃 방법
# [인스타그램 <b>스마트폰</b> 앱의 경우 로그아웃 메뉴를 찾는 경로가 좀 복잡하게 되어 헷갈리는 분은... ▲ <b>스마트폰</b> 앱에서는 [내 로그인 정보 저장] 옵션을 설정할 수 있습니다. 만약 로그인 정보를 저장하기... ]
# 67 : 착한 5G 보급형 <b>스마트폰</b> 모토로라 엣지 30 출시
# [본격적인 국내 출시를 선언한 모토로라에서 이번에는 꽤 매력적인 5G <b>스마트폰</b>을 자급제로 출시하여 화제입니다. 모토로라 엣지30 이라는 모델로 쿠팡을 통해 자급제 <b>스마트폰</b>으로 50만원 중후반대에... ]
# 68 : 중1 아들, <b>스마트폰</b> 득템...ㅠ.ㅠ.
# [<b>스마트폰</b>도 아니고 전화만 잘 되면 크게 불편함이 없었기 때문에 그럭저럭 잘 쓰고 있었지요. 첫째의... 첫째의 핸드폰이 공신폰에서 <b>스마트폰</b>으로 탈바꿈되었거든요.ㅠ.ㅠ. 메인보드가 삭아서 전화가 안 되었던... ]
# 69 : 농협 공동인증서 가져오기/내보내기 다른 <b>스마트폰</b>에 복사
# [사용하기 위해서는 <b>스마트폰</b> 앱 설치 정보를 확인하며, 주의가 필요한 앱이 탐지되었을 경우 NH 스마트뱅킹 앱 이용이 제한된다는 내용에 동의해야 합니다. 4. 간편 비밀번호 (재)등록 진행 화면이 나타납니다.... ]
# 70 : <b>스마트폰</b> 카메라로 대낮에 장노출 ND필터로 촬영해봤다
# [이걸로 뭐에 어떻게 쓰는지 모른다 <b>스마트폰</b> 카메라용 ND필터 사용하기 <b>스마트폰</b>으로 흐르는 물이 마치 연기처럼 보이는 사진을 찍으려면 노출을 줄이고 셔터 속도는 늦춰서 찍어야 하는데(장노출) 일반... ]
# 71 : 포스트 <b>스마트폰</b>은 XR기기..?
# [<b>스마트폰</b>도 세대가 발전 하면서 MP3 무너뜨리고.. 카메라 무너뜨리고... 불과 10년만에 세상을 이렇게... 프리젠테이션의 정석 지금에서 과거를 돌아보면 옛날에 <b>스마트폰</b> 없이 어떻게 살았나 싶고, 줄... ]
# 72 : 넷플릭스 <b>스마트폰</b>을 떨어뜨렸을 뿐인데 원작소설
# [넷플릭스 최근에 들어가서 보니깐 이 소설을 원작으로 2018년에 일본에서 제작 개봉한 영화 <b>스마트폰</b>을... 우리나라에서도 <b>스마트폰</b>을 떨어뜨렸을 뿐인데 꽤 많이 읽은 것으로 알고 있는데 무려 15쇄나... ]
# 73 : 세도나 <b>스마트폰</b>홀더 튼튼하고 견고해서 추천해요
# [실내에서 <b>스마트폰</b>을 이용해 촬영하는 경우에는 맥세이프 기능을 활용해 삼각대에 거치를 하는데요. 야외에서 촬영을 하게 될 때는 맥세이프로 고정하는 게 살짝 불안하더라구요. 그래서 튼튼하게 <b>스마트폰</b>... ]
# 74 : 삼성 갤럭시 <b>스마트폰</b> 화면 스크롤 캡쳐 방법(스크롤 캡처)
# [삼성 갤럭시 <b>스마트폰</b>은 기본 스크린샷 기능 외에 스크롤 캡처 기능을 제공하고 있어 긴 화면을 한 번에 캡쳐하는 것도 가능한데, 갤럭시 <b>스마트폰</b> 스크롤 캡처 방법을 소개해 보겠다. *갤럭시 <b>스마트폰</b> 화면... ]
# 75 : 인스타 브레인 <b>스마트폰</b> 시대 필독서
# [<b>스마트폰</b> 시대 필독서 몰입을 빼앗긴 시대 똑똑한 뇌 사용법이 궁금하다면? 인스타 브레인 저자 안데르스 한센 출판 동양북스 발매 2020.05.15. <b>스마트폰</b>과 한 몸이 되어버렸어요. <b>스마트폰</b>에 몸만 빼앗긴 게... ]
# 76 : 주민등록증? 이제는 <b>스마트폰</b>으로 간편하게 확인 가능!
# [이제 <b>스마트폰</b>으로 주민등록증 확인이 가능하다고?! <b>스마트폰</b>ⓒ픽사베이(pixabay) / 예시ⓒ행정안전부(보도자료) 여러분께서도 신분증 확인이 필요한 순간, 주민등록증을 깜빡하고 지참하지 않아... ]
# 77 : 디지털 안내사의 도움으로, 어려웠던 <b>스마트폰</b> 사용은 이제 안녕!
# [<b>스마트폰</b>, 키오스크 사용이 더 이상 어렵지 않도록 도움을 주는 디지털 안내사를 소개합니다! 서울시에서 디지털 안내사를 찾아보세요! 디지털 안내사는 어르신들의 이용이 많은 거점을 돌며 다양한 <b>스마트폰</b>... ]
# 78 : 미니 무선핀 아이마이크 M1 유튜브 강의용 <b>스마트폰</b> 추천
# [강의용으로 <b>스마트폰</b>에 연결해서 잡음 없는 소리를 녹음할 수 있는 추천 제품입니다 핸드폰으로... 아이마이크 <b>스마트폰</b> 무선마이크 M1은 어플 없이도 사용이 가능하고 360도 무지향성 사운드 픽업으로 주파수... ]
# 79 : 삼성 갤럭시 <b>스마트폰</b>, 문자앱 개선희망점
# [모바일, 통신/앱,프로그램 삼성 갤럭시 <b>스마트폰</b>, 문자앱 개선희망점 https://pcgeeks.tistory.com... (0) 2022.10.03 삼성전자 갤럭시 <b>스마트폰</b> 스크린샷 기능 개선희망점 (0) 2022.09.24 기상청... ]
# 80 : 작년에도 올해도 예쁜 <b>스마트폰</b>터치장갑 추천
# [있는 스마트 터치 홀의 스무스한 터치감~ 내 손가락이 닿는거라 터치 잘되나요? 이런 질문 자체가 필요없는 <b>스마트폰</b>터치장갑 (๑˃̵ᴗ˂̵)و 수족냉증이 있는 나라 겨울 방한용품은 진짜 필수 중에 필수인데... ]
# 81 : 이태원 애도기간 출사 - 패럴<b>스마트폰</b>영화제
# [패럴<b>스마트폰</b>영화제 이태원 참사에도 불구하고 영화제는 취소 없이 진행됨 만약 취소됐으면 1년 동안... 노들섬 다목적홀 11월 5일, 패럴<b>스마트폰</b> 영화제 구경하러 노들섬에 갔습니다. 거기까지 가기 전에... ]
# 82 : <b>스마트폰</b> 메타마스크 지갑에서 NFT 불러오기
# [메타마스크 지갑은 PC버전과 <b>스마트폰</b> 버전을 비교해 보면 다른점을 발견 할 수 있습니다. ▲PC화면 ▲<b>스마트폰</b>화면 위 그림에서 왼쪽 PC번엔은 활동이라고 되어 있고 <b>스마트폰</b> 버전에는 NFT라는... ]
# 83 : [디자인팁] <b>스마트폰</b>으로 꽃 사진 찍기 팁 5가지
# [오늘은 <b>스마트폰</b>으로 꽃 사진을 찍는 저만의 팁을 공유합니다. ^^ 예쁜 꽃을 보면 그냥 지나가는게... 가까워지도록 <b>스마트폰</b>을 돌려주세요. 위의 흑백사진을 보시면 기본적으로 <b>스마트폰</b> 그대로 들고 찍는... ]
# 84 : <b>스마트폰</b> 과의존 연령대가 점점 낮아지고 있다.
# [<b>스마트폰</b>은 인터넷과 연결되어 SNS, 게임, 동영상 시청 등을 손쉽게 할 수 있도록 해 주는 매우 편리한 도구이다. 하지만 <b>스마트폰</b>으로 SNS나 게임을 하는 것을 멈출 수 없게 되어 수면 시간을 줄여가며... ]
# 85 : [해랑] 2022 해운대 행복한 가족 <b>스마트폰</b> 사진 공모전 참여방법
# [개최되는 <b>스마트폰</b> 사진 공모전 소식을 전해드리겠습니다. 2022 해운대 행복한 가족 <b>스마트폰</b> 사진 공모전 2022 해운대 행복한 가족 <b>스마트폰</b> 사진 공모전은 가족의 행복한 모습을 담은 사진을 주제로 부산... ]
# 86 : 설악산 단풍/ 모녀 단풍여행 / <b>스마트폰</b> 단풍 촬영
# [이번엔 <b>스마트폰</b>으로만 촬영했고 무보정이다. 보정할 필요가 없이 완벽하다. 딸이 먼저 설악산... #갤럭시s21 #<b>스마트폰</b>단풍촬영 #모녀단풍여행 #여행은발로하는독서 #여행은발로쓰는수필 #2022설악산단풍... ]
# 87 : <b>스마트폰</b> 터치장갑 매드고트 캐시미어 장갑 추천
# [벗고 폰 만질일이 없어요! 외출할 때 매드고트 <b>스마트폰</b> 터치장갑 여성 캐시미어 장갑 착용해본 모습이에요:-) 어떠한 데일리룩에도 잘 어우러지는 베이지/파스텔 그린 컬러 포인트! 예쁘다 예뻐 ☆ <b>스마트폰</b>... ]
# 88 : 블루투스 무선이어폰 <b>스마트폰</b> 연결 방법
# [컴퓨터와 <b>스마트폰</b>에서 사용하고 싶다. 오늘은 블루투스 이어폰 사용법 © srikanth262, 출처 Unsplash 블루투스 무선 이어폰 lg ㅗㅠㄴ80 블루투스 무선이어폰 <b>스마트폰</b> 연결 방법 1&gt; 무선이어폰 전원을 켠다. 2... ]
# 89 : <b>스마트폰</b> 중독에 걸린 아이의 새로운 변신 스톱모션
# [<b>스마트폰</b> 과의존에서 벗어나 건강한 모습을 되찾아가는 아이의 모습을 보며 <b>스마트폰</b>을 스마트하게 사용하는 방법을 영상으로 확인해 보세요 아래 스톱모션을 영상으로 준비했습니다~ <b>스마트폰</b>을 조금... ]
# 90 : 지토스 <b>스마트폰</b> 거치대 사용 후기
# [지토스 <b>스마트폰</b> 히든 스탠드 거치대 케이스 가격 : 14,900원 아이폰이 매년 출시되면서 디자인적인 면이... 색상도 클리어화이트, 딥오션블루, 매트블랙 이렇게 총 3가지 색상이기 때문에 본인의 폰, 취향에 맞는... ]
# 91 : 제안서에 쓰기 좋은 <b>스마트폰</b> 활용 양식 무료 PPT 템플릿
# [오늘 소개해 할 양식은 <b>스마트폰</b>을 활용한 양식이에요. 일전에도 <b>스마트폰</b>을 활용한 양식을 만들어 올린적이 있는데, 당시에는 민트 컬러라는 특수한 PPT 라서 여러 컬러가 있는 양식으로 만들어 봤습니다.... ]
# 92 : 겨울장갑 추천 월동준비: <b>스마트폰</b> 터치장갑 아미먼트 장갑
# [작년에도 <b>스마트폰</b> 터치 겨울장갑을 포스팅했는데 벌써 새로운 장갑 포스팅이라뇨, 시간이 너무 빠르게... 겨울장갑 <b>스마트폰</b> 터치장갑 해리뷰 시작할게요 겨울장갑도 트렌드가 있는 것 같아요 단색보다는... ]
# 93 : 딱 좋은 눈높이로 보는 즐거움 <b>스마트폰</b> 거치대
# [평소에 <b>스마트폰</b>이나 태블릿을 손으로 들고 볼 때 고개를 자연스럽게 숙이게 되죠? 목이 아픈 걸 잘 못... 두꺼운 <b>스마트폰</b> 케이스나 케이블도 문제없네요. 폭 10cm 높이 17cm 가량되어 슬림하면서도 안정적이어서... ]
# 94 : 공모전 추천 - 제3회 국립광주과학관 <b>스마트폰</b> 천체사진 공모전
# [<b>스마트폰</b> 천체사진 공모전 안녕하세요. 국립광주과학관입니다. 공모전 참여에 관심이 많으신 분이라면 오늘 #공모전추천 포스팅에 주목~ 국립광주과학관에서는 천문우주를 주제로 <b>스마트폰</b> 천체사진... ]
# 95 : [책상] Z의 <b>스마트폰</b> - 박영준
# [싶은 | <b>스마트폰</b>은 스마트하게, 일상을 지키는 ‘진화된 도구’로 사용한다 | 건강한 루틴을 추구하는 삶, #프로갓생러와 #K-댓걸의 탄생 | 우리가 말하는 공정은 그런 게 아니고요 2. ‘밀어서 잠금 해제’... ]
# 96 : 보라색 손뜨개 <b>스마트폰</b> 가방
# [가벼운 나들이나 운동을 나갈 때 <b>스마트폰</b>만 넣고 외출하기 좋답니다. 심플하면서도 쫀쫀한 뜨개... 제 <b>스마트폰</b>이 조금 큰 편인데 케이스를 끼운 상태에서도 넉넉히 잘 들어가는 크기입니다. 하지만... ]
# 97 : 국내 <b>스마트폰</b> 시장을 진단하는 글을 작성할 예정입니다.
# [2022년에 국내 <b>스마트폰</b> 시장에서는 다양한 이슈가 있었습니다. 삼성 갤럭시 <b>스마트폰</b>의 GOS 사태, 모토로라의 국내 시장 재진출, LG가 사업을 철수해서 출시하지 못한 세계 최초 롤러블폰의 중고나라 등장 등..... ]
# 98 : 가을 감성 사진 <b>스마트폰</b>으로 잘 찍는법
# [짙어가는 가을을 남기고자 낙엽이 떨어진 가을 풍경을 <b>스마트폰</b>으로 남겨보았어요. 사진찍는안현정이 <b>스마트폰</b>으로 촬영한 가을 감성 사진 스타일 소개합니다. 가을 감성 사진 <b>스마트폰</b>으로 찍는법 - 가을 단풍... ]
# 99 : 갤럭시, 아이폰 <b>스마트폰</b> 무료 강의 합니다!(10/30)
# [여러분, 무료 <b>스마트폰</b> 활용 기본 강의를 실시합니다! * 이 강의는 <b>스마트폰</b> 활용 초보분들이 듣기 좋은 가벼운 강의 입니다. ✅ 강의 날짜 * 2022년 10월 30일(일) 7시~8시(1시간) ✅ 강의 형태 * 유튜브... ]
# 100 : [마녀의다락방]<b>스마트폰</b> 터치 장갑 여성 초등학생 중학생...
# [안녕하세요 마녀의다락방입니다 추운날씨에 꼬옥 필요한장갑 부드러운소재와 <b>스마트폰</b> 터치가... 나가요~~ <b>스마트폰</b> 터치 장갑 (중) 초등학생 추천 <b>스마트 폰</b> 터치 겨울 장갑 선물 크리스마스 초등학생 중학생... ]

# %%
dataList #JSON
# Out:
# {'lastBuildDate': 'Fri, 18 Nov 2022 10:09:22 +0900',
#  'total': 7616399,
#  'start': 1,
#  'display': 100,
#  'items': [{'title': '<b>스마트폰</b> 속도가 2배로 빨라져서 속이 뻥 뚫리는 방법',
#    'link': 'https://blog.naver.com/kag8023/222773944062',
#    'description': '<b>스마트폰</b> 속도가 2배로 빨라져서 속이 뻥 뚫리는 방법 <b>스마트폰</b> 속도가 느려져서 휴대폰을 바꿔야 하나 하는 생각을 해본적이 있나요? 그렇다면 오늘 포스팅 읽고 10초안에 해결이 가능할 것 같습니다~ 뭘... ',
#    'bloggername': 'SNS컨텐츠연구소',
#    'bloggerlink': 'blog.naver.com/kag8023',
#    'postdate': '20220618'},
#   {'title': 'LTE <b>스마트폰</b>, 삼성 갤럭시 A23 간단 후기',
#    'link': 'https://blog.naver.com/mobano/222853938587',
#    'description': '오늘 저와 함께 살펴볼 제품은 LTE <b>스마트폰</b>, 삼성 갤럭시 A23입니다. 이 제품은 제가 지난 6월 중순에... 이 제품은 퀄컴의 스냅드래곤 680을 프로세서로 사용하는 전형적인 보급형 <b>스마트폰</b>인데요. LPDDR4X... ',
#    'bloggername': '모바노',
#    'bloggerlink': 'blog.naver.com/mobano',
#    'postdate': '20220821'},
#   {'title': '<b>스마트폰</b> 부업으로 매달 수익 내는 중',
#    'link': 'https://blog.naver.com/marie81a/222916067111',
#    'description': '남자, 여자 할 것 없이 누구나 할 수 있는 <b>스마트폰</b> 부업이 인기를 끌고 있는데요 <b>스마트폰</b>으로 할 수 있는 부업 종류는 여러 가지가 있지만 그중 가장 쉽게 진행하면서 매달 안정적인 수익을 낼 수 있는 것은... ',
#    'bloggername': '해피해피♬',
#    'bloggerlink': 'blog.naver.com/marie81a',
#    'postdate': '20221104'},
#   {'title': '<b>스마트폰</b>마이크 소형마이크 난 이거',
#    'link': 'https://blog.naver.com/hott0116/222901049158',
#    'description': '<b>스마트폰</b>마이크 소형마이크 난 이거 선택 아이와 영상 촬영을 자주 하다 보니 소형 마이크의 필요성을... <b>스마트폰</b>으로 연결이 되니 화면을 녹화하고 마스크를 착용하고 사용하고 있습니다. 마이크를 들지 않고... ',
#    'bloggername': '초긍정녀의 다이어리',
#    'bloggerlink': 'blog.naver.com/hott0116',
#    'postdate': '20221015'},
#   {'title': '내 집 도어락 <b>스마트폰</b> 이나 카드로 여는법 (1분이면 끝)',
#    'link': 'https://blog.naver.com/lupangneo/222888475057',
#    'description': '오늘의 꿀팁 요즘 집에 열쇠키가 아닌 스마트 도어락으로 되어서 비번을 누르고 문을 열게 설정이... 오늘은 이런거 필요 없이 한방에 손쉽게 내 <b>스마트폰</b>이나 카드로 여는 방법을 알려드릴꺼에요. 내 집이나... ',
#    'bloggername': 'Dr.만수르',
#    'bloggerlink': 'blog.naver.com/lupangneo',
#    'postdate': '20221001'},
#   {'title': '삼각대 <b>스마트폰</b> 홀더 세도나 안정적인 마운트',
#    'link': 'https://blog.naver.com/oksk2002kr/222919706943',
#    'description': '우리는 일상생활에서 카메라, <b>스마트폰</b> 삼각대를 사용할 때 쓰이는 홀더에 관하여 이야기하려고... 박스를 열어보았을 때 구성품은 삼각대 <b>스마트폰</b> 홀더 하나였어요. 단순히 보조 역할만 할 것 같았지만 높은... ',
#    'bloggername': '티보의 IT 리뷰 공작소',
#    'bloggerlink': 'blog.naver.com/oksk2002kr',
#    'postdate': '20221104'},
#   {'title': '내PC돌보미 국가에서 지원하는 PC, <b>스마트폰</b> 해킹 무료 보안점검',
#    'link': 'https://blog.naver.com/kamine_c/222921254057',
#    'description': '물론 이번 사고는 해킹과는 상관없었지만 기업, 개인들의 PC 나 <b>스마트폰</b> 해킹으로 인한 크고 작은... PC 뿐만 아니라 <b>스마트폰</b>도 마찬가지죠? 그나마 아이폰은 보안이 철저해서 좀 덜하다고 하지만 여전히 해킹... ',
#    'bloggername': '까미네',
#    'bloggerlink': 'blog.naver.com/kamine_c',
#    'postdate': '20221106'},
#   {'title': 'ipTIME C타입허브 맥북허브 <b>스마트폰</b>에 연결해봤어요',
#    'link': 'https://blog.naver.com/namys12/222909577843',
#    'description': '아이피타임허브를 <b>스마트폰</b>과 연결한 후 마우스와도 연결하였는데요 그러면 폰 화면속에 화살표커서가 나타나는데 기본적으로 작은 검은색이라 잘 안보이기도 합니다 크기설정을 어디서 하는지는... ',
#    'bloggername': '행복한 세상을 위하여',
#    'bloggerlink': 'blog.naver.com/namys12',
#    'postdate': '20221025'},
#   {'title': '아이 <b>스마트폰</b> 영상 노출에 대한 고민',
#    'link': 'https://blog.naver.com/p0899/222924531227',
#    'description': '아이 <b>스마트폰</b> 영상 노출에 대한 고민고민 안보여주는게 좋다는 건 알고 있지만 알고 있어도 어쩔 수 없이 보여줄 수밖에 없다면 ? 엄빠라면 아이 <b>스마트폰</b> 영상 노출에 대한 고민 많이들 하실 거 같애,,, 나도... ',
#    'bloggername': '지금이 제일 좋아_얼렁뚱땅 육아 & 일상 ♡',
#    'bloggerlink': 'blog.naver.com/p0899',
#    'postdate': '20221109'},
#   {'title': '포코 X4 GT 스펙분석, 최고의 LCD <b>스마트폰</b>',
#    'link': 'https://blog.naver.com/copy98/222921317123',
#    'description': '많었던 <b>스마트폰</b>입니다. X3 GT의 후속 모델인 X4 GT는 X3보다 훨씬 뛰어난 성능과 144Hz 주사율로... 돌비비전을 지원한다는점도 특징인데, 이는 샤오미가 LCD <b>스마트폰</b>의 화질과 완성도에도 어느정도 관심을... ',
#    'bloggername': 'IT매니아의 잇생',
#    'bloggerlink': 'blog.naver.com/copy98',
#    'postdate': '20221108'},
#   {'title': '<b>스마트폰</b>짐벌 셀카봉삼각대 추천 후기',
#    'link': 'https://blog.naver.com/kim8327809/222903873602',
#    'description': '그래서 <b>스마트폰</b>짐벌기능을 가지고 있는 셀카봉삼각대에 눈길이 갔습니다 모자 나노 SE 스마트본 짐벌 셀카봉 색상은 블랙과 민트 2가지가 있는데 전 민트색상을 개인적으로 좋아해서 민트색상으로... ',
#    'bloggername': '쮸쮸chu블로그',
#    'bloggerlink': 'blog.naver.com/kim8327809',
#    'postdate': '20221021'},
#   {'title': '<b>스마트폰</b>어플개발,어렵지않아요!',
#    'link': 'https://blog.naver.com/simon9627/222862211716',
#    'description': '보시는 것처럼 스마트메이커는 가상의 <b>스마트폰</b> 화면에 원하는 기능이나 창을 드래그 앤 드롭 하는 것만으로도 어플을 만들 수 있습니다. 정말 쉬워 보이죠? 스마트메이커의 사용법은 2시간 무료 동영상만 따라... ',
#    'bloggername': '스마트메이커',
#    'bloggerlink': 'blog.naver.com/simon9627',
#    'postdate': '20220830'},
#   {'title': '<b>스마트폰</b> 중독 문제점과 아날로그 감성의 필요성',
#    'link': 'https://blog.naver.com/with127031/222920062165',
#    'description': '<b>스마트폰</b> 중독은 이제 중독이라고 부르기도 민망할 정도로 엄청난 파급력으로 생활 전반을 지배하고... © the_average_tech_guy, 출처 Unsplash 카카오톡 문제는 일단락 되었지만 <b>스마트폰</b>이 우리 일상생활에서... ',
#    'bloggername': '쿠이의 건강한생활',
#    'bloggerlink': 'blog.naver.com/with127031',
#    'postdate': '20221104'},
#   {'title': '충전기 없이 <b>스마트폰</b> 배터리 충전 방법과 배터리 85% 충전 설정',
#    'link': 'https://blog.naver.com/kag8023/222881607896',
#    'description': '충전기 없이 <b>스마트폰</b> 배터리 충전 방법과 배터리 85% 충전 설정 요즘 <b>스마트폰</b> 없이 외출하려면 왠지 불안한 생각마저 듭니다. 왜냐하면 <b>스마트폰</b> 안에는 은행관련 카드, 주민등록증, 면허증, 교통카드 등등... ',
#    'bloggername': 'SNS컨텐츠연구소',
#    'bloggerlink': 'blog.naver.com/kag8023',
#    'postdate': '20220923'},
#   {'title': '갤럭시 보급형 <b>스마트폰</b> A52S A53 A73 자급제 가격... ',
#    'link': 'https://blog.naver.com/dicagallery/222910818948',
#    'description': '갤럭시 보급형 <b>스마트폰</b> 3형제 A52S A53 A73 자급제폰 가격 대비 성능비교하니 A52S가 레전드로 남은... LG가 <b>스마트폰</b> 사업을 포기하면서 합리적인 가격의 쓸만한 보급형 <b>스마트폰</b>을 찾기가 더... ',
#    'bloggername': '함영민의 디카갤러리',
#    'bloggerlink': 'blog.naver.com/dicagallery',
#    'postdate': '20221026'},
#   {'title': '[유진쌤의 조금은 고지식한 이야기] <b>스마트폰</b>, 언제 사줘야 할까?',
#    'link': 'https://blog.naver.com/naverschool/222894337639',
#    'description': '알아보니 공신폰(<b>스마트폰</b>과 똑 닮았지만 인터넷이 차단된 폰)은 오히려 요금제 같은 것들을 포함하면... 게다가 요즘은 학교마다 태블릿과 같은 스마트 기기들이 잘 구비되어 있기 때문에 <b>스마트폰</b>이 없다고... ',
#    'bloggername': '스쿨잼',
#    'bloggerlink': 'blog.naver.com/naverschool',
#    'postdate': '20221007'},
#   {'title': '삼성 갤럭시 와이드6 가성비 5G <b>스마트폰</b>, 추천 사용자는?',
#    'link': 'https://blog.naver.com/todshrck/222870510333',
#    'description': '삼성 <b>스마트폰</b> 가성비 라인업인 Galaxy Wide 시리즈의 신작 갤럭시 와이드6 (SM-A136SB)가 출시되었습니다. 대화면과 대용량 배터리, 쿼드 카메라를 탑재한 5G <b>스마트폰</b>이고요. 전작과 마찬가지로 SK텔레콤 단독... ',
#    'bloggername': 'mangsangk.com',
#    'bloggerlink': 'blog.naver.com/todshrck',
#    'postdate': '20220908'},
#   {'title': '카카오톡 메신저 쉽게 가입하기, <b>스마트폰</b>강사 김미경 교육',
#    'link': 'https://blog.naver.com/kyoung37/222872313056',
#    'description': 'SNS <b>스마트폰</b>강사 김미경 인사드려요. 추석연휴 잘 보내고 계시지요. 카카오톡으로도 명절 추석인사... 하지만 노인복지관, 경로당, 평생학습관 등 <b>스마트폰</b>활용교육 하다보면 카카오톡 가입 안되신 분들이 1~2분... ',
#    'bloggername': '김미경 SNS 스마트폰교육',
#    'bloggerlink': 'blog.naver.com/kyoung37',
#    'postdate': '20220911'},
#   {'title': '<b>스마트폰</b> 속으로 쏙 들어온 ‘모바일 운전면허증’ 발급 후기',
#    'link': 'https://blog.naver.com/withbupyeong/222878656339',
#    'description': '<b>스마트폰</b> 속으로 쏙 들어온 운전면허증, 모바일 운전면허증을 발급받아 사용해 봤어요. 2022년 7월 28일부터 <b>스마트폰</b>의 운전면허증을 신분확인 용도로 발급받아 사용할 수 있게 되었다는 소식 들으셨죠? 사실... ',
#    'bloggername': '부평구청 블로그 공감부평',
#    'bloggerlink': 'blog.naver.com/withbupyeong',
#    'postdate': '20220919'},
#   {'title': '[모닝 어반] <b>스마트폰</b> 거치대 설치',
#    'link': 'https://blog.naver.com/hok97/222910579248',
#    'description': '가장 먼저 할 튜닝은 <b>스마트폰</b> 거치대 작업입니다. 저는 가장 기본형인 컴팩트 오디오 장착 모델을 선택했기 때문에 차에 내비게이션이 없어서 <b>스마트폰</b> 앱을 써야 합니다. 모닝 동호회에서 많은 분들이... ',
#    'bloggername': '逐鹿者之房',
#    'bloggerlink': 'blog.naver.com/hok97',
#    'postdate': '20221027'},
#   {'title': '꼭! 알아두자. 중고 <b>스마트폰</b> 구입 시 주의사항!',
#    'link': 'https://blog.naver.com/loginplus365/222894238002',
#    'description': '최근 <b>스마트폰</b>은 전 세계적으로 거의 보편화되었으며, 삼성 갤럭시 폴드4, 아이폰14 PRO 등 프리미엄 <b>스마트폰</b>들은 1년을 주기로 출시되고 있는데요. 하지만 소비자의 기대를 만족시키기 위해 최신... ',
#    'bloggername': '로그인플러스 공식 블로그 - 로그인을 안전하게!',
#    'bloggerlink': 'blog.naver.com/loginplus365',
#    'postdate': '20221011'},
#   {'title': '자녀 <b>스마트폰</b> 관리 어플로 한 후기',
#    'link': 'https://blog.naver.com/taetaej75/222910273757',
#    'description': '등을 <b>스마트폰</b>을 통해서 접하기 때문입니다. 단순 전화 기능만 가능한 스마트 기기를 쓰게 된다면 친구들에게 따돌림을 당할 수도 있고 아이들이 접해야 하는 세상 속 창구를 막아 버릴 가능성도 있습니다.... ',
#    'bloggername': '미니의 하루일상',
#    'bloggerlink': 'blog.naver.com/taetaej75',
#    'postdate': '20221025'},
#   {'title': '귀뚜라미 보일러 <b>스마트폰</b> 사용방법 및 IOT 설치하기',
#    'link': 'https://blog.naver.com/itnamu/222927963109',
#    'description': '#귀뚜라미 #보일러조절기 #보일러원격제어 #보일러<b>스마트폰</b> #IOT보일러 #거꾸로NEW콘덴싱 #귀뚜라미<b>스마트폰</b>사용방법 #귀뚜라미<b>스마트폰</b>설치방법 #귀뚜라미보일러 #방온도조절 #스마트보일러 #스마트조절기... ',
#    'bloggername': 'itnamu의 포토로그',
#    'bloggerlink': 'blog.naver.com/itnamu',
#    'postdate': '20221114'},
#   {'title': '광주휴대폰복구 <b>스마트폰</b> 작동이 안되나요',
#    'link': 'https://blog.naver.com/kimdayun/222839409597',
#    'description': '맡아둔 <b>스마트폰</b>을 뒷주머니에 넣어놓고 깜빡하고 물에 들어갔다가 심지어 떨어트리고 파손까지 시키니까 성질이 확 올라오더라고요. 정말 제가 짜증 제대로 낼 뻔했는데 광주데이터복구에서 <b>스마트폰</b>복구... ',
#    'bloggername': 'URBAN PICNIC SEOUL',
#    'bloggerlink': 'blog.naver.com/kimdayun',
#    'postdate': '20220804'},
#   {'title': '<b>스마트폰</b> 짐벌 dji 오즈모모바일 6 발빠른 사용 후기',
#    'link': 'https://blog.naver.com/bennywhang/222886136072',
#    'description': '사용했음에도 <b>스마트폰</b> 짐벌 라인은 처음이였던 나에게 이 기계는 어떻게 다가왔을까? 글 / 사진 / 영상 Ben Moon 심플한 제품구성, 가벼운 무게로 <b>스마트폰</b> 짐벌 편의성 높여 제품 박스는 요렇게 화이트... ',
#    'bloggername': '벤 문의 세상살이',
#    'bloggerlink': 'blog.naver.com/bennywhang',
#    'postdate': '20220928'},
#   {'title': '<b>스마트폰</b> 터치 등산장갑 착용후기',
#    'link': 'https://blog.naver.com/verymucho/222900251990',
#    'description': '바로 <b>스마트폰</b> 터치가 가능한 등산장갑이라 여러분들께 한번 소개를 해볼까해요 구입한지는 반년이... 단연 <b>스마트폰</b>의 터치 유무였을 거에요 아무래도 한번 착용을 하면 꼈다 뺐다 하는 것이 불편하게 느껴질수... ',
#    'bloggername': '핫초코',
#    'bloggerlink': 'blog.naver.com/verymucho',
#    'postdate': '20221014'},
#   {'title': '갤럭시 <b>스마트폰</b> 배터리 수명 및 오래 사용할 수 있게... ',
#    'link': 'https://blog.naver.com/kag8023/222819089353',
#    'description': '갤럭시 <b>스마트폰</b> 배터리 수명 및 오래 사용할 수 있게 관리하는 법~ 갤럭시 배터리 수명이 다하면 <b>스마트폰</b>을 교체를 해야 하는 일이 발생하기 때문에~ <b>스마트폰</b> 배터리 관리하는 법을 잘 알아야 합니다.... ',
#    'bloggername': 'SNS컨텐츠연구소',
#    'bloggerlink': 'blog.naver.com/kag8023',
#    'postdate': '20220721'},
#   {'title': '추억의<b>스마트폰</b> LG G3, 삼성 갤럭시 A8',
#    'link': 'https://blog.naver.com/ddihw/222896467143',
#    'description': '지금은 사라져버린 LG <b>스마트폰</b>. 한때는 톡톡튀는 기능과 디자인으로 많은 사랑을 받았던 그 핸드폰. 처음이자 마지막으로 사용했던 LG <b>스마트폰</b> G3. 그리고 그 다음 사용하게된 삼성 갤럭시 A8. 두 <b>스마트폰</b>모두... ',
#    'bloggername': '변검',
#    'bloggerlink': 'blog.naver.com/ddihw',
#    'postdate': '20221010'},
#   {'title': 'IT학원 <b>스마트폰</b>으로도 가능한 영상편집 배워봤어요!',
#    'link': 'https://blog.naver.com/gosexy79/222785721772',
#    'description': '프리미어 영상편집 , 유튜브 크리에이팅 영상편집, <b>스마트폰</b>을 이용한 생활영상제작, 에프터이펙트... 제가 수강한 과정은 <b>스마트폰</b>을 이용한 생활영상제작이에요~ 제대로 된 카메라가 있는 것은 아니고 또... ',
#    'bloggername': '후야와 율군이 있어 행복한 세상',
#    'bloggerlink': 'blog.naver.com/gosexy79',
#    'postdate': '20220623'},
#   {'title': '유튜브 촬영장비 3만원 대 아이폰 8핀 <b>스마트폰</b> 무선마이크... ',
#    'link': 'https://blog.naver.com/g9bonyam/222901075253',
#    'description': '다만 한가지 아쉬운점이 있다면, 아이폰은 8핀이라 일반 <b>스마트폰</b> 마이크는 장착할 수 없다는 점. 저는... 싶은데, <b>스마트폰</b>과 거리가 멀어서 음성 녹음이 잘 안 될 때가 있어요. 뷰맛집 캠핑장에서 멍 때리기... ',
#    'bloggername': '이레의 지구본먹기',
#    'bloggerlink': 'blog.naver.com/g9bonyam',
#    'postdate': '20221015'},
#   {'title': '[BP/IT] 손목이 아플 때 태블릿, <b>스마트폰</b> 스탠드',
#    'link': 'https://bruprin.tistory.com/7665',
#    'description': "BP's : 최근에 태블릿, <b>스마트폰</b> 스탠드(거치대)를 몇 개 구입했는데 그 이유는 <b>스마트폰</b>이 무거운데 계속 손으로 들고 있다보니 팔목과 어께에 무리가 가는 것을 느꼈기 때문이다. 알리익스프레스나 쿠팡, 네이버... ",
#    'bloggername': 'Bruprin&apos;s &apos;콘텐츠 있음!&apos;',
#    'bloggerlink': 'https://bruprin.tistory.com/',
#    'postdate': '20221102'},
#   {'title': '강제 디지털 디톡스, <b>스마트폰</b> 액정이 고장 나버린 하루',
#    'link': 'https://blog.naver.com/usunhwa/222906793507',
#    'description': '새 <b>스마트폰</b>을 주문하는 과정에서 인증을 해야 하는데 액정 나간 폰으로 뭘 하겠어요 (•̥̥̥⌓•̥̥̥) 다행히 유심을 다른 폰으로 옮겨서 간단하게 해결되긴 했습니다 강적은 바로 데이터 옮기기. 폰 자체가... ',
#    'bloggername': '행복해지리 즐거워지리',
#    'bloggerlink': 'blog.naver.com/usunhwa',
#    'postdate': '20221021'},
#   {'title': '라이카 M렌즈 교체형 <b>스마트폰</b> 샤오미 12S 울트라',
#    'link': 'https://blog.naver.com/bizzy78/222918337930',
#    'description': '단순한 브랜드 협업 이외에도 꽤 재미있는 <b>스마트폰</b>을 준비하고 있다는 것이 공개되어 화제입니다.... 물론 양산 버전은 아니지만 렌즈교체형 <b>스마트폰</b> 카메라의 가능성을 보여준 것만으로도 상당히 의미... ',
#    'bloggername': '이지이 IT창고',
#    'bloggerlink': 'blog.naver.com/bizzy78',
#    'postdate': '20221103'},
#   {'title': 'UXUI 디자이너의 컴퓨터, 노트북, 탭, <b>스마트폰</b>',
#    'link': 'https://blog.naver.com/datadrivdesignerlucy/222923071760',
#    'description': '<b>스마트폰</b> 다수의 종을 사용합니다. © stux, 출처 Pixabay 데스크탑 조립용 데스크탑과 삼성 모니터를... <b>스마트폰</b> 그리고 다양한 <b>스마트폰</b>이 있으며 종류는 대략 5종... 확인 용입니다. 아이폰 13, 아이폰 6, 갤럭시... ',
#    'bloggername': '루씨의 UXUI 디자인',
#    'bloggerlink': 'blog.naver.com/datadrivdesignerlucy',
#    'postdate': '20221108'},
#   {'title': '아이폰 갤럭시 <b>스마트폰</b> 미러링 프로그램 심플한 Vysor',
#    'link': 'https://blog.naver.com/oyabung0612/222913994170',
#    'description': '<b>스마트폰</b> 화면 미러링 프로그램은 검색을 통해 다양한 종류를 볼 수 있지만 무료는 생각보다 많지... 오늘은 아이폰, 갤럭시 등에서 사용할 수 있는 <b>스마트폰</b> 무료 미러링 프로그램 Vysor에 대해 알아보도록... ',
#    'bloggername': '바람이 분다..',
#    'bloggerlink': 'blog.naver.com/oyabung0612',
#    'postdate': '20221029'},
#   {'title': '[서초구 양성평등활동센터] 이제 나도 <b>스마트폰</b> 영상 제작자!',
#    'link': 'https://blog.naver.com/seocho88/222931335526',
#    'description': '나도 <b>스마트폰</b> 영상 제작가’ 프로그램에 참여했습니다. 11월10일~11일 양일간 오후 2시~5시까지 서초여성가족플라자 잠원센터에서 열렸는데요. <b>스마트폰</b> 영상제작 이론과 실습이 있었어요. 서초구... ',
#    'bloggername': '서초뉴스',
#    'bloggerlink': 'blog.naver.com/seocho88',
#    'postdate': '20221117'},
#   {'title': '차량용 <b>스마트폰</b> 거치대 스마트키 폴딩키 딱이에요!',
#    'link': 'https://blog.naver.com/12w32321/222827841841',
#    'description': '저 외에도 차 키 또는 <b>스마트폰</b>을 깜빡하고 외출하시는 분들이 많은가 봐요^^ 그리고 폴딩키나 스마트키 기판을 옮겨 사용하는 DIY용 케이스 톡이기 때문에 배터리와 PCB 기판을 분해할 때 손상되지 않게 해야... ',
#    'bloggername': '리리의 인테리어',
#    'bloggerlink': 'blog.naver.com/12w32321',
#    'postdate': '20220725'},
#   {'title': '갤럭시a13 가격 0원 요금도 저렴한 보급형 <b>스마트폰</b>',
#    'link': 'https://blog.naver.com/kimdayun/222838890171',
#    'description': '월마다 내는 <b>스마트폰</b> 할부금이나 통신 요금도 가계 생활비 지출에 큰 몫을 차지하고 있습니다. 게다가 갤럭시S 시리즈나 갤럭시 폴더블 시리즈, 아이폰 시리즈 등 프리미엄 최신 <b>스마트폰</b>이라고 할부금, 통신... ',
#    'bloggername': 'URBAN PICNIC SEOUL',
#    'bloggerlink': 'blog.naver.com/kimdayun',
#    'postdate': '20220803'},
#   {'title': '<b>스마트폰</b> 리폼? 갤럭시S20 FE 후면 커버 셀프로 교체',
#    'link': 'https://blog.naver.com/heena_mom/222916343194',
#    'description': '비주입니다...^^ 세상에나 이 <b>스마트폰</b>이 둘째가 가지고 다니는 거에요. 도대체 어떻게 가지고 다니길래... 둘째가 가지고 다니는 <b>스마트폰</b>이 갤럭시S20 FE 모델인데요. 저는 여태까지 뒷면이 유리로 되어 있는지... ',
#    'bloggername': '▒ 희나네집 ▒ 라이프스타일디자이너! : 비주언니',
#    'bloggerlink': 'blog.naver.com/heena_mom',
#    'postdate': '20221101'},
#   {'title': '솔잠 스마트 카본매트 좌우분리와 <b>스마트폰</b> 연동 후기!',
#    'link': 'https://blog.naver.com/zzzz1n/222925579527',
#    'description': '<b>스마트폰</b>에 솔잠 스마트앱을 설치하고 어플을 연상태로 조절기 전원을 켜고 S버튼을 누르면 핸드폰에서 연결가능한 디바이스를 검색해서 블루투스 연결이 됩니다^0^ <b>스마트폰</b>에서 좌우 온도 좌우 타이머를... ',
#    'bloggername': 'DECOMAMA의 맛집,여행기록',
#    'bloggerlink': 'blog.naver.com/zzzz1n',
#    'postdate': '20221110'},
#   {'title': '당신만 모르는 <b>스마트폰</b> 갤러리 앱 활용 5가지 꿀팁',
#    'link': 'https://blog.naver.com/kag8023/222811671688',
#    'description': '당신만 모르는 <b>스마트폰</b> 갤러리 앱 활용 5가지 꿀팁 갤럭시 <b>스마트폰</b> 갤러리에는 카메라 앱은 물론 휴대폰에 설치된 어플을 통해 생성되는 많은 사진과 영상들이 존재합니다. 하지만! 늘 찍고 보관만 하고 있으면... ',
#    'bloggername': 'SNS컨텐츠연구소',
#    'bloggerlink': 'blog.naver.com/kag8023',
#    'postdate': '20220718'},
#   {'title': '우리 아이, <b>스마트폰</b>을 손에서 놓지 않는다면 &apos;이것&apos; 조심하세요!',
#    'link': 'https://blog.naver.com/humc_health/222905273964',
#    'description': '급성 후천성 일치 내사시는 10년 전까지는 드문 질환이었지만, 최근 코로나19로 인해 스마트기기를 이용한 학습이 늘면서 청소년기의 아이들에게 발생이 늘었습니다. <b>스마트폰</b>을 30cm이내로 1시간 이상 지속하여... ',
#    'bloggername': '한림대학교의료원(Hallym University Medical Center)',
#    'bloggerlink': 'blog.naver.com/humc_health',
#    'postdate': '20221020'},
#   {'title': '세도나 <b>스마트폰</b> 홀더 거치대 SSH-360 사용 후기, 흥미롭다.',
#    'link': 'https://blog.naver.com/shiaru/222897980826',
#    'description': '세도나 <b>스마트폰</b> 홀더 거치대 SSH-360에 대해 이야기해 보겠습니다. 미리 언급하지만, 업체로부터 제품을 제공 받았습니다. 휴대폰을 활용해서 유튜브 또는 인스타그램을 촬영하는 분들은 이런 <b>스마트폰</b>... ',
#    'bloggername': '프로그래머의 IT, 영상',
#    'bloggerlink': 'blog.naver.com/shiaru',
#    'postdate': '20221012'},
#   {'title': '오즈모모바일6 핸드폰 <b>스마트폰</b>짐벌 추천',
#    'link': 'https://blog.naver.com/airbag1/222904989413',
#    'description': '추가되어서 <b>스마트폰</b>짐벌로 추천 소개합니다 오즈모모바일6 핸드폰짐벌 구성품으로 짐벌 본체, 세워서 영상을 찍을 수 있는 삼각대, <b>스마트폰</b> 케이스에 부착하는 클램프, 보관용 파우치, 충전 케이블이... ',
#    'bloggername': '슈마여행의 재밌는 IT',
#    'bloggerlink': 'blog.naver.com/airbag1',
#    'postdate': '20221020'},
#   {'title': '벤로코리아 BK10 <b>스마트폰</b> 삼각대 셀카봉 추천',
#    'link': 'https://blog.naver.com/nihaoyoga/222908661451',
#    'description': '<b>스마트폰</b> 삼각대 추천 셀카봉 추천 저는 워낙 운동영상도 매번 찍고 유튜브 영상도 찍어서 <b>스마트폰</b> 삼각대 종류별로 많이 사용했거든요 저가도 사용해보고 고가도 사용해봤는데 이번에 사용한 벤로코리아... ',
#    'bloggername': '써니엄마',
#    'bloggerlink': 'blog.naver.com/nihaoyoga',
#    'postdate': '20221024'},
#   {'title': '<b>스마트폰</b> 카메라 대용량 보조배터리',
#    'link': 'https://blog.naver.com/jun0457/222925538812',
#    'description': '것이 <b>스마트폰</b>을 가지고 다니는 중에 배터리가 없을 때에 당황스럽고 카메라 촬영 중에도 배터리가... 저 같은 사람에게 정말 딱이라고 생각이 되는 제품 100%에서 충전을 시작하고 <b>스마트폰</b> 카메라 등을... ',
#    'bloggername': '좋은생각황병준',
#    'bloggerlink': 'blog.naver.com/jun0457',
#    'postdate': '20221110'},
#   {'title': 'Type C <b>스마트폰</b>, PC나 TV화면에 출력하기',
#    'link': 'https://blog.naver.com/kwshop88/222831182028',
#    'description': '이 컨버터를 사용하면 충전 단자가 Type C인 최신 <b>스마트폰</b>이나 애플 노트북과 같은 맥북을 커다란... 그러면 이제 이 컨버터를 이용해 <b>스마트폰</b>을 TV에 연결해 틀어보겠습니다. 별도의 HDMI 케이블... ',
#    'bloggername': '강자의 IT놀이',
#    'bloggerlink': 'blog.naver.com/kwshop88',
#    'postdate': '20220727'},
#   {'title': '[교내 활동] <b>스마트폰</b> 사용 줄이기 캠페인 구상',
#    'link': 'https://blog.naver.com/hehe26/222924988472',
#    'description': '위한 <b>스마트폰</b> 다이어트 프로그램운영이 있다(<b>스마트폰</b> 다이어트라니!). 담임교사일 때 경험해본... 또 슬러지·큐레이션·스마트 공개·맞춤형 기본 설정 등 새롭게 등장한 선택 설계 아이디어들을 소개하고... ',
#    'bloggername': '가늘고 길게 가는 블로그.',
#    'bloggerlink': 'blog.naver.com/hehe26',
#    'postdate': '20221110'},
#   {'title': '삼성 <b>스마트폰</b> 갤럭시 공장 초기화 방법 1분만에 해결',
#    'link': 'https://blog.naver.com/lucky_box7/222861439119',
#    'description': '<b>스마트폰</b>을 사용하면서 초기화가 필요한 순간이 종종 있습니다. 새로운 단말기를 구매해 기존 <b>스마트폰</b>을 중고로 판매하는 순간이나 사용하면서 너무 느려졌다고 느껴진다면 포맷을 통해 다시 빠릿한 느낌을... ',
#    'bloggername': 'Cwon&apos;s Life',
#    'bloggerlink': 'blog.naver.com/lucky_box7',
#    'postdate': '20220829'},
#   {'title': '<b>스마트폰</b>MMORPG 카오스포털 CBT 일정 및 이벤트 소식',
#    'link': 'https://blog.naver.com/12512512/222905757753',
#    'description': '지난번에 <b>스마트폰</b>MMORPG 신작 카오스포털에 대해서 소개 드린 적이 있습니다. 거대한 포털을 타고... 단순히 혼자서만 성장하는 <b>스마트폰</b>MMORPG가 아니라 강해지는 루트가 다양하다고 할 수 있겠습니다.... ',
#    'bloggername': '피스타임 블로그',
#    'bloggerlink': 'blog.naver.com/12512512',
#    'postdate': '20221020'},
#   {'title': '<b>스마트폰</b> 밸류체인 (아이폰 &amp; 갤럭시 비교)',
#    'link': 'https://blog.naver.com/dicecasts/222926571633',
#    'description': '자화전자, 덕우전자, 비에이치 등 공부하기 전에 <b>스마트폰</b> 밸류체인 다시 한 번 복습 오래간만에 텔레그램 자료실에 올려 둔 자료를 꺼내옴 현재 <b>스마트폰</b> 비지니스쪽이 전반적으로 슬로우한 상황 아마... ',
#    'bloggername': '지적호기심.활자중독.새로운 시도',
#    'bloggerlink': 'blog.naver.com/dicecasts',
#    'postdate': '20221112'},
#   {'title': '<b>스마트폰</b> sd 메모리 카드 인식 불량 저장장치 복구',
#    'link': 'https://blog.naver.com/rudals2632/222899455531',
#    'description': '요즘은 보통 <b>스마트폰</b> 사용할 때 SD 메모리 카드가 들어가는 걸 사용하지는 않는거 같아요 하지만 저는... 부득이하게 <b>스마트폰</b>을 바꿔야하는 일이 있으면 되도록 SD 메모리 카드가 들어갈 수 있는 모델을... ',
#    'bloggername': 'IM',
#    'bloggerlink': 'blog.naver.com/rudals2632',
#    'postdate': '20221013'},
#   {'title': '안드로이드 <b>스마트폰</b> 스캔 어플 브이플랫 vFlat',
#    'link': 'https://blog.naver.com/bookey3/222898392458',
#    'description': '<b>스마트폰</b>으로 할 수 있는 일이 참 많죠? 그중에서 오늘은 안드로이드 스캔 어플 알려드릴게요 편리하고 간단하게 <b>스마트폰</b> 스캔 가능한 브이플랫 vFlat 앱 예전에는 스캔 한번 하려면 스캐너가 있어야 했고 또... ',
#    'bloggername': '우쿠리의 빼꼼한 정보수납장',
#    'bloggerlink': 'blog.naver.com/bookey3',
#    'postdate': '20221013'},
#   {'title': '긴급상황 시! <b>스마트폰</b> SOS 메시지 보내기로 위기탈출~',
#    'link': 'https://blog.naver.com/kag8023/222803663265',
#    'description': '<b>스마트폰</b> SOS 메시지 보내기로 위기탈출~ 세상살이 힘들고 위급할 때 있는 거 맞죠? 어떤 상황에서... 위와 같은 설정이 완성되면 비로소 스마트으로 SOS 메시지 보내기가 시작됩니다. 만약에 경찰 112에... ',
#    'bloggername': 'SNS컨텐츠연구소',
#    'bloggerlink': 'blog.naver.com/kag8023',
#    'postdate': '20220708'},
#   {'title': '[서평이벤트(~22일)] <b>스마트폰</b> 10분만요 / 조윤주 / 인성동화... ',
#    'link': 'https://blog.naver.com/indiecat/222929320463',
#    'description': '서평단 모집 <b>스마트폰</b> 10분만요 날아라 꼬꼬 할머니 인성동화 어린이 &gt; 국내창작동화 발행일 2022년 11월... 이번에는 하루 종일 <b>스마트폰</b> 게임을 하고 싶어 하는 아이에게 출동했다! 가족들과 함께하는 외식... ',
#    'bloggername': '인디캣책곳간',
#    'bloggerlink': 'blog.naver.com/indiecat',
#    'postdate': '20221115'},
#   {'title': '<b>스마트폰</b> 때문에 헤어지는 경우?',
#    'link': 'https://blog.naver.com/j02wrath/222924838448',
#    'description': '<b>스마트폰</b>은 현대인의 필수품이죠. 24시간 몸에 붙어있다고 해도 과언이 아닙니다. 물론 사랑하는 연인과 연락하게 해주는 고마운 도구이기도 하지만 사실 이 <b>스마트폰</b> 때문에 싸우고, 연애가 깨지는 경우도 적지... ',
#    'bloggername': '큐피트 타로',
#    'bloggerlink': 'blog.naver.com/j02wrath',
#    'postdate': '20221110'},
#   {'title': '리버티샵 유튜브 <b>스마트폰</b> 삼각대 (카메라 거치대 추천)',
#    'link': 'https://blog.naver.com/oa1885oa/222908891752',
#    'description': '오늘의 포스팅 #리버트샵 #유튜브<b>스마트폰</b>삼각대 #삼각대 입니다. 평소 가족사진을 찍거나 혼자 블로그 포스팅할 제품을 촬영할 때 자주 사용하는 #<b>스마트폰</b>삼각대 얼마전 기존 삼각대가 부숴져서 새로운... ',
#    'bloggername': '흥청망청♥',
#    'bloggerlink': 'blog.naver.com/oa1885oa',
#    'postdate': '20221024'},
#   {'title': '아이폰도 편리한 <b>스마트폰</b>무선마이크 COMS 소형마이크',
#    'link': 'https://blog.naver.com/ksy7298/222901093470',
#    'description': '아이폰도 사용하기 편리한 COMS <b>스마트폰</b>무선마이크 요리할때 종종 동영상도 찍어보기 때문에 나름... COMS <b>스마트폰</b> 소형마이크입니다 구성도 심플해요 마이크 수신부와 송신부 그리고 8핀젠더와 충전용USB 끝!... ',
#    'bloggername': '두사람식탁',
#    'bloggerlink': 'blog.naver.com/ksy7298',
#    'postdate': '20221015'},
#   {'title': '삼각대셀카봉 <b>스마트폰</b>짐벌 기능까지 한번에~MOZA NANO SE',
#    'link': 'https://blog.naver.com/crom234/222907218263',
#    'description': '#<b>스마트폰</b>셀카봉 #<b>스마트폰</b>삼각대 #삼각대셀카봉 #<b>스마트폰</b>짐벌 #MOZANANOSE #사진촬영 #사진잘찍는법 #수평맞추기 사진을 찍으면서 잘 찍고 싶은 마음은 누구나 같다. 사진을 잘 찍는다는 것은 쉽지 않은 일이지만... ',
#    'bloggername': '피터팬 캠핑:차박 캠핑으로 떠나는 여행!',
#    'bloggerlink': 'blog.naver.com/crom234',
#    'postdate': '20221022'},
#   {'title': '2022년 청소년 <b>스마트폰</b> 가족치유캠프에서 힐링하고 가요!',
#    'link': 'https://blog.naver.com/hongane2013/222864682615',
#    'description': '요즘 정보화로 인해서 <b>스마트폰</b> 없는 청소년들은 찾아보기 힘들거라고 생각해요. 그래서 인지 <b>스마트폰</b> 중독까지 와서 화면으로 들어갈 정도로 <b>스마트폰</b>을 사용하는 청소년들이 많아졌어요. <b>스마트폰</b>... ',
#    'bloggername': '순천시 공식블로그',
#    'bloggerlink': 'blog.naver.com/hongane2013',
#    'postdate': '20220902'},
#   {'title': '페어폰 벤치마킹? 노키아가 내놓은 착한 <b>스마트폰</b>',
#    'link': 'https://blog.naver.com/tech-plus/222864985474',
#    'description': '보급형 <b>스마트폰</b> X30 5G를 선보였다고 전했다. HMD 글로벌은 이전 노키아 직원들이 설립한 회사다. 지난 2016년 노키아 <b>스마트폰</b> 사업부를 일부 인수했다. 이후부터 노키아 이름을 단 저가 <b>스마트폰</b>을... ',
#    'bloggername': '테크플러스',
#    'bloggerlink': 'blog.naver.com/tech-plus',
#    'postdate': '20220902'},
#   {'title': '<b>스마트폰</b>이 바꾸고 있는 우크라이나 전쟁',
#    'link': 'https://blog.naver.com/tech-plus/222766074522',
#    'description': '‘<b>스마트폰</b>’을 활용한 국민 참여는 생각보다 전쟁 지원에 많은 도움이 되는 것으로 보인다. 지난 3월... 우크라이나 국민들은 전쟁 상황을 <b>스마트폰</b>으로 촬영해 러시아의 침공을 세계에 알리는 큰 역할을... ',
#    'bloggername': '테크플러스',
#    'bloggerlink': 'blog.naver.com/tech-plus',
#    'postdate': '20220609'},
#   {'title': '삼성 갤럭시 <b>스마트폰</b>, 크롬 모바일 앱 다크모드 설정 방법',
#    'link': 'https://blog.naver.com/winsweet/222910231168',
#    'description': '삼성 갤럭시 <b>스마트폰</b>과 크롬 모바일 앱의 다크모드 적용 방법을 보여드릴게요. 눈의 피로를 줄여줄 수 있을 뿐 아니라, OLED 패널을 탑재한 <b>스마트폰</b>을 사용하고 있다면 다크모드 적용만으로 배터리 소모를... ',
#    'bloggername': 'Play IT',
#    'bloggerlink': 'blog.naver.com/winsweet',
#    'postdate': '20221025'},
#   {'title': 'usb없이 <b>스마트폰</b> 데이터(사진,동영상) pc로 옮기기 (삼성... ',
#    'link': 'https://blog.naver.com/elmyeong/222907762524',
#    'description': '안녕하세요 <b>스마트폰</b>에있는 사진이나 동영상등을 옮길때 다들 어떻게하시나요? 생각보다 회사 사업계획서나 포스팅이나 레포트를 할때 <b>스마트폰</b>에 있는 데이터를 예전에는 삼성... ',
#    'bloggername': '운명이 패를돌리면 우리는 거기에 거는거야!',
#    'bloggerlink': 'blog.naver.com/elmyeong',
#    'postdate': '20221023'},
#   {'title': '윈도우 스티커메모 <b>스마트폰</b> 원노트와 동기화 해두세요',
#    'link': 'https://blog.naver.com/oyabung0612/222916548055',
#    'description': '텐데요, <b>스마트폰</b>에 원노트 앱 설치 후 동기화하면 윈도우 스티커 메모를 더 유용하게 활용할 수... 다음으로 <b>스마트폰</b> 앱스토어, 플레이스토어로 이동해서 Microsoft OneNote를 검색하고 설치합니다. 설치가... ',
#    'bloggername': '바람이 분다..',
#    'bloggerlink': 'blog.naver.com/oyabung0612',
#    'postdate': '20221101'},
#   {'title': '인스타그램 <b>스마트폰</b> 앱, PC 버전 로그아웃 방법',
#    'link': 'https://blog.naver.com/winsweet/222906638330',
#    'description': '인스타그램 <b>스마트폰</b> 앱의 경우 로그아웃 메뉴를 찾는 경로가 좀 복잡하게 되어 헷갈리는 분은... ▲ <b>스마트폰</b> 앱에서는 [내 로그인 정보 저장] 옵션을 설정할 수 있습니다. 만약 로그인 정보를 저장하기... ',
#    'bloggername': 'Play IT',
#    'bloggerlink': 'blog.naver.com/winsweet',
#    'postdate': '20221021'},
#   {'title': '착한 5G 보급형 <b>스마트폰</b> 모토로라 엣지 30 출시',
#    'link': 'https://blog.naver.com/bizzy78/222908937243',
#    'description': '본격적인 국내 출시를 선언한 모토로라에서 이번에는 꽤 매력적인 5G <b>스마트폰</b>을 자급제로 출시하여 화제입니다. 모토로라 엣지30 이라는 모델로 쿠팡을 통해 자급제 <b>스마트폰</b>으로 50만원 중후반대에... ',
#    'bloggername': '이지이 IT창고',
#    'bloggerlink': 'blog.naver.com/bizzy78',
#    'postdate': '20221024'},
#   {'title': '중1 아들, <b>스마트폰</b> 득템...ㅠ.ㅠ.',
#    'link': 'https://blog.naver.com/wlsgur705/222918270450',
#    'description': '<b>스마트폰</b>도 아니고 전화만 잘 되면 크게 불편함이 없었기 때문에 그럭저럭 잘 쓰고 있었지요. 첫째의... 첫째의 핸드폰이 공신폰에서 <b>스마트폰</b>으로 탈바꿈되었거든요.ㅠ.ㅠ. 메인보드가 삭아서 전화가 안 되었던... ',
#    'bloggername': '☆작가진쌤의 이야기™',
#    'bloggerlink': 'blog.naver.com/wlsgur705',
#    'postdate': '20221103'},
#   {'title': '농협 공동인증서 가져오기/내보내기 다른 <b>스마트폰</b>에 복사',
#    'link': 'https://blog.naver.com/okyoky2000/222867697023',
#    'description': '사용하기 위해서는 <b>스마트폰</b> 앱 설치 정보를 확인하며, 주의가 필요한 앱이 탐지되었을 경우 NH 스마트뱅킹 앱 이용이 제한된다는 내용에 동의해야 합니다. 4. 간편 비밀번호 (재)등록 진행 화면이 나타납니다.... ',
#    'bloggername': '블루스피넬 IT Blog',
#    'bloggerlink': 'blog.naver.com/okyoky2000',
#    'postdate': '20220905'},
#   {'title': '<b>스마트폰</b> 카메라로 대낮에 장노출 ND필터로 촬영해봤다',
#    'link': 'https://blog.naver.com/syk1792/222925932930',
#    'description': '이걸로 뭐에 어떻게 쓰는지 모른다 <b>스마트폰</b> 카메라용 ND필터 사용하기 <b>스마트폰</b>으로 흐르는 물이 마치 연기처럼 보이는 사진을 찍으려면 노출을 줄이고 셔터 속도는 늦춰서 찍어야 하는데(장노출) 일반... ',
#    'bloggername': '캐럴만 듣는 남자',
#    'bloggerlink': 'blog.naver.com/syk1792',
#    'postdate': '20221111'},
#   {'title': '포스트 <b>스마트폰</b>은 XR기기..?',
#    'link': 'https://blog.naver.com/0bin823/222929816758',
#    'description': '<b>스마트폰</b>도 세대가 발전 하면서 MP3 무너뜨리고.. 카메라 무너뜨리고... 불과 10년만에 세상을 이렇게... 프리젠테이션의 정석 지금에서 과거를 돌아보면 옛날에 <b>스마트폰</b> 없이 어떻게 살았나 싶고, 줄... ',
#    'bloggername': '와이빈의 블로그',
#    'bloggerlink': 'blog.naver.com/0bin823',
#    'postdate': '20221116'},
#   {'title': '넷플릭스 <b>스마트폰</b>을 떨어뜨렸을 뿐인데 원작소설',
#    'link': 'https://blog.naver.com/bookpark/222931292561',
#    'description': '넷플릭스 최근에 들어가서 보니깐 이 소설을 원작으로 2018년에 일본에서 제작 개봉한 영화 <b>스마트폰</b>을... 우리나라에서도 <b>스마트폰</b>을 떨어뜨렸을 뿐인데 꽤 많이 읽은 것으로 알고 있는데 무려 15쇄나... ',
#    'bloggername': '책맛집',
#    'bloggerlink': 'blog.naver.com/bookpark',
#    'postdate': '20221117'},
#   {'title': '세도나 <b>스마트폰</b>홀더 튼튼하고 견고해서 추천해요',
#    'link': 'https://blog.naver.com/mellowryu/222895039500',
#    'description': '실내에서 <b>스마트폰</b>을 이용해 촬영하는 경우에는 맥세이프 기능을 활용해 삼각대에 거치를 하는데요. 야외에서 촬영을 하게 될 때는 맥세이프로 고정하는 게 살짝 불안하더라구요. 그래서 튼튼하게 <b>스마트폰</b>... ',
#    'bloggername': '제이크의 언박싱',
#    'bloggerlink': 'blog.naver.com/mellowryu',
#    'postdate': '20221008'},
#   {'title': '삼성 갤럭시 <b>스마트폰</b> 화면 스크롤 캡쳐 방법(스크롤 캡처)',
#    'link': 'https://blog.naver.com/korovo/222915999663',
#    'description': '삼성 갤럭시 <b>스마트폰</b>은 기본 스크린샷 기능 외에 스크롤 캡처 기능을 제공하고 있어 긴 화면을 한 번에 캡쳐하는 것도 가능한데, 갤럭시 <b>스마트폰</b> 스크롤 캡처 방법을 소개해 보겠다. *갤럭시 <b>스마트폰</b> 화면... ',
#    'bloggername': '잡동사니 저장소',
#    'bloggerlink': 'blog.naver.com/korovo',
#    'postdate': '20221101'},
#   {'title': '인스타 브레인 <b>스마트폰</b> 시대 필독서',
#    'link': 'https://blog.naver.com/boronia/222924806534',
#    'description': '<b>스마트폰</b> 시대 필독서 몰입을 빼앗긴 시대 똑똑한 뇌 사용법이 궁금하다면? 인스타 브레인 저자 안데르스 한센 출판 동양북스 발매 2020.05.15. <b>스마트폰</b>과 한 몸이 되어버렸어요. <b>스마트폰</b>에 몸만 빼앗긴 게... ',
#    'bloggername': '글쓰는 워킹맘의 성장클래스',
#    'bloggerlink': 'blog.naver.com/boronia',
#    'postdate': '20221110'},
#   {'title': '주민등록증? 이제는 <b>스마트폰</b>으로 간편하게 확인 가능!',
#    'link': 'https://blog.naver.com/mopaspr/222884395003',
#    'description': '이제 <b>스마트폰</b>으로 주민등록증 확인이 가능하다고?! <b>스마트폰</b>ⓒ픽사베이(pixabay) / 예시ⓒ행정안전부(보도자료) 여러분께서도 신분증 확인이 필요한 순간, 주민등록증을 깜빡하고 지참하지 않아... ',
#    'bloggername': '대한민국 행정안전부',
#    'bloggerlink': 'blog.naver.com/mopaspr',
#    'postdate': '20220926'},
#   {'title': '디지털 안내사의 도움으로, 어려웠던 <b>스마트폰</b> 사용은 이제 안녕!',
#    'link': 'https://blog.naver.com/swf1004/222881278508',
#    'description': '<b>스마트폰</b>, 키오스크 사용이 더 이상 어렵지 않도록 도움을 주는 디지털 안내사를 소개합니다! 서울시에서 디지털 안내사를 찾아보세요! 디지털 안내사는 어르신들의 이용이 많은 거점을 돌며 다양한 <b>스마트폰</b>... ',
#    'bloggername': '서울시복지재단 공식블로그',
#    'bloggerlink': 'blog.naver.com/swf1004',
#    'postdate': '20220922'},
#   {'title': '미니 무선핀 아이마이크 M1 유튜브 강의용 <b>스마트폰</b> 추천',
#    'link': 'https://blog.naver.com/airbag1/222911200473',
#    'description': '강의용으로 <b>스마트폰</b>에 연결해서 잡음 없는 소리를 녹음할 수 있는 추천 제품입니다 핸드폰으로... 아이마이크 <b>스마트폰</b> 무선마이크 M1은 어플 없이도 사용이 가능하고 360도 무지향성 사운드 픽업으로 주파수... ',
#    'bloggername': '슈마여행의 재밌는 IT',
#    'bloggerlink': 'blog.naver.com/airbag1',
#    'postdate': '20221026'},
#   {'title': '삼성 갤럭시 <b>스마트폰</b>, 문자앱 개선희망점',
#    'link': 'https://pcgeeks.tistory.com/21337',
#    'description': '모바일, 통신/앱,프로그램 삼성 갤럭시 <b>스마트폰</b>, 문자앱 개선희망점 https://pcgeeks.tistory.com... (0) 2022.10.03 삼성전자 갤럭시 <b>스마트폰</b> 스크린샷 기능 개선희망점 (0) 2022.09.24 기상청... ',
#    'bloggername': 'PC Geek&apos;s',
#    'bloggerlink': 'https://pcgeeks.tistory.com/',
#    'postdate': '20221005'},
#   {'title': '작년에도 올해도 예쁜 <b>스마트폰</b>터치장갑 추천',
#    'link': 'https://blog.naver.com/jannet_j/222917092830',
#    'description': '있는 스마트 터치 홀의 스무스한 터치감~ 내 손가락이 닿는거라 터치 잘되나요? 이런 질문 자체가 필요없는 <b>스마트폰</b>터치장갑 (๑˃̵ᴗ˂̵)و 수족냉증이 있는 나라 겨울 방한용품은 진짜 필수 중에 필수인데... ',
#    'bloggername': '세상의 빛',
#    'bloggerlink': 'blog.naver.com/jannet_j',
#    'postdate': '20221102'},
#   {'title': '이태원 애도기간 출사 - 패럴<b>스마트폰</b>영화제',
#    'link': 'https://blog.naver.com/wjdgns1102/222931484425',
#    'description': '패럴<b>스마트폰</b>영화제 이태원 참사에도 불구하고 영화제는 취소 없이 진행됨 만약 취소됐으면 1년 동안... 노들섬 다목적홀 11월 5일, 패럴<b>스마트폰</b> 영화제 구경하러 노들섬에 갔습니다. 거기까지 가기 전에... ',
#    'bloggername': '또이 라 응어이 한 꾸옥',
#    'bloggerlink': 'blog.naver.com/wjdgns1102',
#    'postdate': '20221117'},
#   {'title': '<b>스마트폰</b> 메타마스크 지갑에서 NFT 불러오기',
#    'link': 'https://blog.naver.com/mobilos/222907412230',
#    'description': '메타마스크 지갑은 PC버전과 <b>스마트폰</b> 버전을 비교해 보면 다른점을 발견 할 수 있습니다. ▲PC화면 ▲<b>스마트폰</b>화면 위 그림에서 왼쪽 PC번엔은 활동이라고 되어 있고 <b>스마트폰</b> 버전에는 NFT라는... ',
#    'bloggername': 'NFT Art',
#    'bloggerlink': 'blog.naver.com/mobilos',
#    'postdate': '20221022'},
#   {'title': '[디자인팁] <b>스마트폰</b>으로 꽃 사진 찍기 팁 5가지',
#    'link': 'https://blog.naver.com/designcoach/222911756313',
#    'description': '오늘은 <b>스마트폰</b>으로 꽃 사진을 찍는 저만의 팁을 공유합니다. ^^ 예쁜 꽃을 보면 그냥 지나가는게... 가까워지도록 <b>스마트폰</b>을 돌려주세요. 위의 흑백사진을 보시면 기본적으로 <b>스마트폰</b> 그대로 들고 찍는... ',
#    'bloggername': '아는디자이너 크는언니 ::: 작은브랜딩+자기계발',
#    'bloggerlink': 'blog.naver.com/designcoach',
#    'postdate': '20221027'},
#   {'title': '<b>스마트폰</b> 과의존 연령대가 점점 낮아지고 있다.',
#    'link': 'https://blog.naver.com/weizmann_why/222893558933',
#    'description': '<b>스마트폰</b>은 인터넷과 연결되어 SNS, 게임, 동영상 시청 등을 손쉽게 할 수 있도록 해 주는 매우 편리한 도구이다. 하지만 <b>스마트폰</b>으로 SNS나 게임을 하는 것을 멈출 수 없게 되어 수면 시간을 줄여가며... ',
#    'bloggername': '와이즈만 영재교육 공식블로그',
#    'bloggerlink': 'blog.naver.com/weizmann_why',
#    'postdate': '20221006'},
#   {'title': '[해랑] 2022 해운대 행복한 가족 <b>스마트폰</b> 사진 공모전 참여방법',
#    'link': 'https://blog.naver.com/hudpr/222884518627',
#    'description': '개최되는 <b>스마트폰</b> 사진 공모전 소식을 전해드리겠습니다. 2022 해운대 행복한 가족 <b>스마트폰</b> 사진 공모전 2022 해운대 행복한 가족 <b>스마트폰</b> 사진 공모전은 가족의 행복한 모습을 담은 사진을 주제로 부산... ',
#    'bloggername': '다시 새롭게! 희망과 활력이 넘치는 해운대❤️',
#    'bloggerlink': 'blog.naver.com/hudpr',
#    'postdate': '20220926'},
#   {'title': '설악산 단풍/ 모녀 단풍여행 / <b>스마트폰</b> 단풍 촬영',
#    'link': 'https://blog.naver.com/gracepark69/222912046957',
#    'description': '이번엔 <b>스마트폰</b>으로만 촬영했고 무보정이다. 보정할 필요가 없이 완벽하다. 딸이 먼저 설악산... #갤럭시s21 #<b>스마트폰</b>단풍촬영 #모녀단풍여행 #여행은발로하는독서 #여행은발로쓰는수필 #2022설악산단풍... ',
#    'bloggername': '은혜의 샘',
#    'bloggerlink': 'blog.naver.com/gracepark69',
#    'postdate': '20221027'},
#   {'title': '<b>스마트폰</b> 터치장갑 매드고트 캐시미어 장갑 추천',
#    'link': 'https://blog.naver.com/ssong920/222922068579',
#    'description': '벗고 폰 만질일이 없어요! 외출할 때 매드고트 <b>스마트폰</b> 터치장갑 여성 캐시미어 장갑 착용해본 모습이에요:-) 어떠한 데일리룩에도 잘 어우러지는 베이지/파스텔 그린 컬러 포인트! 예쁘다 예뻐 ☆ <b>스마트폰</b>... ',
#    'bloggername': 'H A F F Y H A A : L O G',
#    'bloggerlink': 'blog.naver.com/ssong920',
#    'postdate': '20221107'},
#   {'title': '블루투스 무선이어폰 <b>스마트폰</b> 연결 방법',
#    'link': 'https://blog.naver.com/iq211/222931289424',
#    'description': '컴퓨터와 <b>스마트폰</b>에서 사용하고 싶다. 오늘은 블루투스 이어폰 사용법 © srikanth262, 출처 Unsplash 블루투스 무선 이어폰 lg ㅗㅠㄴ80 블루투스 무선이어폰 <b>스마트폰</b> 연결 방법 1&gt; 무선이어폰 전원을 켠다. 2... ',
#    'bloggername': '이경애 강사 IT교육',
#    'bloggerlink': 'blog.naver.com/iq211',
#    'postdate': '20221117'},
#   {'title': '<b>스마트폰</b> 중독에 걸린 아이의 새로운 변신 스톱모션',
#    'link': 'https://blog.naver.com/ki116/222918001573',
#    'description': '<b>스마트폰</b> 과의존에서 벗어나 건강한 모습을 되찾아가는 아이의 모습을 보며 <b>스마트폰</b>을 스마트하게 사용하는 방법을 영상으로 확인해 보세요 아래 스톱모션을 영상으로 준비했습니다~ <b>스마트폰</b>을 조금... ',
#    'bloggername': '깨끗한 세상, 신우아빠 Lifelog',
#    'bloggerlink': 'blog.naver.com/ki116',
#    'postdate': '20221103'},
#   {'title': '지토스 <b>스마트폰</b> 거치대 사용 후기',
#    'link': 'https://blog.naver.com/ky151915/222892510911',
#    'description': '지토스 <b>스마트폰</b> 히든 스탠드 거치대 케이스 가격 : 14,900원 아이폰이 매년 출시되면서 디자인적인 면이... 색상도 클리어화이트, 딥오션블루, 매트블랙 이렇게 총 3가지 색상이기 때문에 본인의 폰, 취향에 맞는... ',
#    'bloggername': '다양한 꿀팁 정보',
#    'bloggerlink': 'blog.naver.com/ky151915',
#    'postdate': '20221005'},
#   {'title': '제안서에 쓰기 좋은 <b>스마트폰</b> 활용 양식 무료 PPT 템플릿',
#    'link': 'https://blog.naver.com/egmenti/222882253594',
#    'description': '오늘 소개해 할 양식은 <b>스마트폰</b>을 활용한 양식이에요. 일전에도 <b>스마트폰</b>을 활용한 양식을 만들어 올린적이 있는데, 당시에는 민트 컬러라는 특수한 PPT 라서 여러 컬러가 있는 양식으로 만들어 봤습니다.... ',
#    'bloggername': '에그먼티 IT 일상다반사',
#    'bloggerlink': 'blog.naver.com/egmenti',
#    'postdate': '20220923'},
#   {'title': '겨울장갑 추천 월동준비: <b>스마트폰</b> 터치장갑 아미먼트 장갑',
#    'link': 'https://blog.naver.com/hrhriiii/222910604758',
#    'description': '작년에도 <b>스마트폰</b> 터치 겨울장갑을 포스팅했는데 벌써 새로운 장갑 포스팅이라뇨, 시간이 너무 빠르게... 겨울장갑 <b>스마트폰</b> 터치장갑 해리뷰 시작할게요 겨울장갑도 트렌드가 있는 것 같아요 단색보다는... ',
#    'bloggername': 'live and let live',
#    'bloggerlink': 'blog.naver.com/hrhriiii',
#    'postdate': '20221025'},
#   {'title': '딱 좋은 눈높이로 보는 즐거움 <b>스마트폰</b> 거치대',
#    'link': 'https://blog.naver.com/kwshop88/222897171682',
#    'description': '평소에 <b>스마트폰</b>이나 태블릿을 손으로 들고 볼 때 고개를 자연스럽게 숙이게 되죠? 목이 아픈 걸 잘 못... 두꺼운 <b>스마트폰</b> 케이스나 케이블도 문제없네요. 폭 10cm 높이 17cm 가량되어 슬림하면서도 안정적이어서... ',
#    'bloggername': '강자의 IT놀이',
#    'bloggerlink': 'blog.naver.com/kwshop88',
#    'postdate': '20221011'},
#   {'title': '공모전 추천 - 제3회 국립광주과학관 <b>스마트폰</b> 천체사진 공모전',
#    'link': 'https://blog.naver.com/sciencenter/222899391373',
#    'description': '<b>스마트폰</b> 천체사진 공모전 안녕하세요. 국립광주과학관입니다. 공모전 참여에 관심이 많으신 분이라면 오늘 #공모전추천 포스팅에 주목~ 국립광주과학관에서는 천문우주를 주제로 <b>스마트폰</b> 천체사진... ',
#    'bloggername': '국립광주과학관님의 블로그',
#    'bloggerlink': 'blog.naver.com/sciencenter',
#    'postdate': '20221013'},
#   {'title': '[책상] Z의 <b>스마트폰</b> - 박영준',
#    'link': 'https://blog.naver.com/mahastha/222913843204',
#    'description': '싶은 | <b>스마트폰</b>은 스마트하게, 일상을 지키는 ‘진화된 도구’로 사용한다 | 건강한 루틴을 추구하는 삶, #프로갓생러와 #K-댓걸의 탄생 | 우리가 말하는 공정은 그런 게 아니고요 2. ‘밀어서 잠금 해제’... ',
#    'bloggername': '가능태공간-독서.투자.여행',
#    'bloggerlink': 'blog.naver.com/mahastha',
#    'postdate': '20221110'},
#   {'title': '보라색 손뜨개 <b>스마트폰</b> 가방',
#    'link': 'https://blog.naver.com/kek1382/222929481731',
#    'description': '가벼운 나들이나 운동을 나갈 때 <b>스마트폰</b>만 넣고 외출하기 좋답니다. 심플하면서도 쫀쫀한 뜨개... 제 <b>스마트폰</b>이 조금 큰 편인데 케이스를 끼운 상태에서도 넉넉히 잘 들어가는 크기입니다. 하지만... ',
#    'bloggername': '소느로',
#    'bloggerlink': 'blog.naver.com/kek1382',
#    'postdate': '20221115'},
#   {'title': '국내 <b>스마트폰</b> 시장을 진단하는 글을 작성할 예정입니다.',
#    'link': 'https://blog.naver.com/ox1997cow/222918201151',
#    'description': '2022년에 국내 <b>스마트폰</b> 시장에서는 다양한 이슈가 있었습니다. 삼성 갤럭시 <b>스마트폰</b>의 GOS 사태, 모토로라의 국내 시장 재진출, LG가 사업을 철수해서 출시하지 못한 세계 최초 롤러블폰의 중고나라 등장 등..... ',
#    'bloggername': '전설의컴덕이 이야기하는 디지털 세상',
#    'bloggerlink': 'blog.naver.com/ox1997cow',
#    'postdate': '20221103'},
#   {'title': '가을 감성 사진 <b>스마트폰</b>으로 잘 찍는법',
#    'link': 'https://blog.naver.com/yyee2002/222924673377',
#    'description': '짙어가는 가을을 남기고자 낙엽이 떨어진 가을 풍경을 <b>스마트폰</b>으로 남겨보았어요. 사진찍는안현정이 <b>스마트폰</b>으로 촬영한 가을 감성 사진 스타일 소개합니다. 가을 감성 사진 <b>스마트폰</b>으로 찍는법 - 가을 단풍... ',
#    'bloggername': '사진찍는 안현정의 이안공감 스냅',
#    'bloggerlink': 'blog.naver.com/yyee2002',
#    'postdate': '20221109'},
#   {'title': '갤럭시, 아이폰 <b>스마트폰</b> 무료 강의 합니다!(10/30)',
#    'link': 'https://blog.naver.com/its_snowing/222908042857',
#    'description': '여러분, 무료 <b>스마트폰</b> 활용 기본 강의를 실시합니다! * 이 강의는 <b>스마트폰</b> 활용 초보분들이 듣기 좋은 가벼운 강의 입니다. ✅ 강의 날짜 * 2022년 10월 30일(일) 7시~8시(1시간) ✅ 강의 형태 * 유튜브... ',
#    'bloggername': '100억 담이',
#    'bloggerlink': 'blog.naver.com/its_snowing',
#    'postdate': '20221023'},
#   {'title': '[마녀의다락방]<b>스마트폰</b> 터치 장갑 여성 초등학생 중학생... ',
#    'link': 'https://blog.naver.com/gusdnr0409/222929898053',
#    'description': '안녕하세요 마녀의다락방입니다 추운날씨에 꼬옥 필요한장갑 부드러운소재와 <b>스마트폰</b> 터치가... 나가요~~ <b>스마트폰</b> 터치 장갑 (중) 초등학생 추천 <b>스마트 폰</b> 터치 겨울 장갑 선물 크리스마스 초등학생 중학생... ',
#    'bloggername': '세 남자와 함께하는 소소한이야기',
#    'bloggerlink': 'blog.naver.com/gusdnr0409',
#    'postdate': '20221116'}]}

# %%
dataList["items"][0]["description"] #"description"이란 key로 저장된 것을 읽겠다.

# %%
title = []
desc = []
for data in dataList["items"]: #items라는 이름으로 보관된 리스트가 추출된다. 그 안에는 JSON형식으로 검색한 결과가 있고 그 중에서 title 부분과 description ㅂ분만 꺼낸거다.
    title.append(data["title"]) #title이란 리스트에다가 append
    desc.append(data["description"]) #desc라는 리스트에다가 append

# %%
len(title)

# %%
len(desc)

# %%
title

# %%
import re
for i in range(len(title)) :
   title[i] = re.sub("</?b>", "", title[i]) #<b>나 </b>는 삭제해라.

# %%
for i in range(len(desc)) :
   desc[i] = re.sub("</?b>", "", desc[i])

# %%
import pandas as pd
dictdata = {"title":title,"description":desc} #딕셔너리를 만들어서
df = pd.DataFrame(dictdata) #판다스의 데이터프레임으로 구성한다.
df #변수명만 주면 자동으로 display()가 적용된다. #RStudio는 사용했던 객체들을 프로그램을 종료할 때 저장할건지 묻는데 쥬피터랩은 아니다. 종료되면 다시 초기화된다.

# %%
df.to_csv("output/smartphone.csv")

# %%
import urllib.request
import json

client_key = 'izGsqP2exeThwwEUVU3x'
client_secret = 'WrwbQ1l6ZI'
query = '오징어게임'
encText = urllib.parse.quote_plus(query)

num = 100
naver_url = 'https://openapi.naver.com/v1/search/news.json?query=' + encText + '&display=' + str(num)

request = urllib.request.Request(naver_url)
request.add_header("X-Naver-Client-Id",client_key)
request.add_header("X-Naver-Client-Secret",client_secret) #네이버가 정해놓은 방식대로 받은 key와 secret을 http 프로토콜의 헤더에 추가한다.
response = urllib.request.urlopen(request)

rescode = response.getcode() #getcode()는 응답상태코드를 리턴해준다. 

if(rescode == 200): #응답 상태 코드가 200이란 것은 성공했다는 뜻.
    response_body = response.read()
    dataList = json.loads(response_body)#loads()를 통해 딕셔너리로 만든다. 그리고 key:value 쌍으로 되어있는 것을 필요한것을 추출해 사용한다.
    count = 1
    print('[' + query + '에 대한 네이버 뉴스 글 ]')
    for data in dataList['items'] :
        print (str(count) + ' : ' + data['title'])
        print ('[' + data['description'] + ']')
        count += 1
else: #200이 아니면 오류코드 출력
    print('오류 코드 : ' + rescode)
# Out:
# [오징어게임에 대한 네이버 뉴스 글 ]
# 1 : 정부, &quot;새 수출동력 서비스산업 혁신 박차…서비스발전법 입법&quot;
# [추 부총리는 &quot;최근 BTS, <b>오징어게임</b> 등 우리의 다양한 문화·콘텐츠가 세계적으로 각광받으며 새로운 성장·수출동력으로 부상하고 있다&quot;면서 &quot;그러나 국내 서비스산업 생산성은 경제협력개발기구(OECD) 평균의 70% 수준에... ]
# 2 : 돼지고기 금지인 카타르…벤투호는 점심엔 닭·저녁엔 소
# [카타르에서는 과거 아시아축구연맹(AFC) 아시안컵, 하계 아시안<b>게임</b> 등 국제대회를 개최해왔고 돼지고기를... 17일 점심으로는 청국장과 닭도리탕, 도미구이를, 저녁으로는 참치김치찌개와 소고기 후추 볶음, <b>오징어</b> 볶음... ]
# 3 : 세계 경제에 놓인 ‘7가지 덫’…2023 산업 대전망
# [‘<b>오징어 게임</b>’을 닮은 역환율 전쟁 2023년 벌어질 역환율 전쟁은 ‘<b>오징어 게임</b>’에 비유했다. 감독은 Fed와 미국 재무부, 주연은 달러화, 조연은 원화를 비롯한 각국의 통화, 시나리오 구성은 서바이벌 데스 게임이다.... ]
# 4 : BIFF에서 ‘글로벌 OTT 어워즈’ 행사 열린다…정부, OTT 육성 위해 BIFF 활용...
# [글로벌 히트작이된 ‘<b>오징어게임</b>’이 에미상 등 해외 주요 시상식에서 수상하면서 ‘K 콘텐츠’의 위상을 높였던 것처럼 우수한 국내 콘텐츠를 시상식을 통해 알리겠다는 의도다. 부산국제영화제와 연계된 글로벌 OTT... ]
# 5 : 빅데이터로 분석한 한국 모바일 시장 마케팅
# [하지만 그 이후, 중국에 의존했던 KPOP팝과 드라마, 영화는 굉장히 치열하게 경쟁력을 확보해 살아남을 수 있었고, 불과 5년 만에 빌보드 차트 1위, 아카데미상 대상, <b>오징어 게임</b>으로 대표되는 글로벌 신드롬으로... ]
# 6 : 서비스산업 &apos;개혁 과제&apos;...추경호 &quot;산업발전기본법 입법 추진&quot;
# [추 부총리 &quot;최근 BTS, <b>오징어게임</b> 등 우리의 다양한 문화·콘텐츠가 세계적으로 각광받으며 새로운 성장·수출동력으로 부상하고 있다&quot;며 &quot;그러나 국내 서비스산업 생산성은 경제협력개발기구(OECD) 평균의 70% 수준에 불과해... ]
# 7 : &apos;서비스발전법&apos; 재입법…추경호 &quot;트렌드 반영되도록 보완&quot;
# [그는 &quot;최근 BTS, <b>오징어게임</b> 등 우리의 다양한 문화·콘텐츠가 세계적으로 각광받으며 새로운 성장·수출동력으로 부상하고 있다&quot;며 &quot;그러나 국내 서비스산업 생산성은 경제협력개발기구(OECD) 평균의 70% 수준에 불과해... ]
# 8 : 정부, 미디어 콘텐츠 활성화에 과감한 &apos;개혁 드라이브&apos;
# [그는 &quot;방탄소년단(BTS), <b>오징어게임</b> 등 우리의 다양한 문화·콘텐츠가 세계적으로 각광받으며 새로운 성장·수출동력이 됐다&quot;고 평가했다. 그러면서 온라인동영상서비스(OTT) 등 새로운 미디어 플랫폼이 확산하는 상황에... ]
# 9 : 추경호 &quot;서비스산업 구조개혁 필요…&apos;서발법&apos; 입법화 추진&quot;
# [추 부총리는 &quot;서비스산업은 전체 고용의 70%, 부가가치의 60% 이상을 차지하는 우리 경제의 근간을 이루는 중추 산업&quot;이라며 &quot;최근 BTS, <b>오징어게임</b> 등 다양한 문화·콘텐츠가 세계적으로 각광받으며 새로운 성장... ]
# 10 : [인터뷰] 버클리 엑솔라 CMO &quot;한국은 세계 <b>게임</b>의 중심&quot;
# [가령 한국 게임이나 K-POP이나 &apos;<b>오징어게임</b>&apos; 등 알고 있는 한류도 소개해달라. A. 테크, 광고, 엔터테인먼트 업계에서 20년 이상 일했다. 2년 6개월 전 엑솔라에 합류한 이후에는, 새로운 마케팅 및 콘텐츠 전략을 도입하여... ]
# 11 : 정부, 토종OTT 해외진출 물꼬 튼다
# [사진=이미지투데이 韓 OTT, 해외 시장으로 무대 확장 ‘<b>오징어게임</b>’과 같이 국내에서 만들어진 콘텐츠는 글로벌 OTT 플랫폼에서 큰 인기를 끌고 있다. 콘텐츠의 경쟁력은 입증되고 있지만 토종 OTT 플랫폼은 투자 규모에서... ]
# 12 : 추경호, 서비스발전법 입법 추진…내년 구조개혁 5개년 계획 발표
# [그는 &quot;최근 BTS, <b>오징어게임</b> 등 우리의 다양한 문화·콘텐츠가 세계적으로 각광받으며 새로운 성장·수출동력으로 부상하고 있다&quot;며 &quot;그러나 국내 서비스산업 생산성은 경제협력개발기구(OECD) 평균의 70% 수준에 불과해... ]
# 13 : 추경호 “서비스산업은 새 성장·수출동력…서비스발전법 입법”
# [그는 “최근 BTS, <b>오징어게임</b> 등 우리의 다양한 문화·콘텐츠가 세계적으로 각광받으며 새로운 성장·수출동력으로 부상하고 있다”며 “그러나 국내 서비스산업 생산성은 경제협력개발기구(OECD) 평균의 70% 수준에... ]
# 14 : 추경호 &quot;서비스산업은 새 성장·수출동력…서비스발전법 입법&quot;
# [추 부총리는 &quot;최근 BTS(방탄소년단), <b>오징어게임</b> 등 우리의 다양한 문화·콘텐트가 세계적으로 각광받으며 새로운 성장·수출동력으로 부상하고 있다&quot;며 &quot;그러나 국내 서비스산업 생산성은 경제협력개발기구(OECD) 평균의... ]
# 15 : &quot;BTS·블랙핑크 &apos;땡큐&apos;&quot;…日 안 가고 한국 찾는 외국인들 [이미경의 인사이트...
# [올해는 넷플릭스의 한국 드라마 &apos;<b>오징어게임</b>&apos;이 미국 방송계 최고 권위인 에미상 시상식에서 감독상과 남우주연상, 게스트상 등 6개 부문에서 수상했다. K콘텐츠의 인기는 그대로 한국에 대한 호감도 상승으로 이어졌다.... ]
# 16 : 추경호 &quot;&apos;서발법&apos; 입법 재추진…OTT 제작비용 세액공제&quot;(종합)
# [&quot;서비스산업발전TF 이달 구성…&apos;서발법&apos; 입법 재추진&quot; 추 부총리는 &quot;서비스산업은 전체 고용의 70%, 부가가치의 60% 이상을 차지하는 우리 경제의 근간을 이루는 중추 산업으로 최근 BTS, <b>오징어게임</b> 등 다양한 문화·콘텐츠가... ]
# 17 : 추경호 &quot;서비스산업 우리 경제의 중추…서비스발전법 입법 조속히 추진&quot;
# [그는 &quot;서비스산업은 전체 고용의 70%, 부가가치의 60% 이상을 차지하는 등 우리 경제의 근간을 이루고 있는 중추산업&quot;이라며 &quot;최근 BTS, <b>오징어게임</b> 등 우리의 다양한 문화·콘텐츠가 세계적으로 각광받으며 새로운 성장... ]
# 18 : 추경호 부총리 &quot;내년 초 서비스산업 5개년 계획 발표&quot;
# [이날 추 부총리는 &quot;서비스산업은 전체 고용의 70%, 부가가치의 60% 이상을 차지하는 우리 경제의 근간을 이루는 중추 산업으로 최근 BTS, <b>오징어게임</b> 등 다양한 문화·콘텐츠가 세계적으로 각광받으며 새로운 성장... ]
# 19 : 11년된 &apos;서비스발전법안&apos; 손질…추경호 &quot;트렌드 반영해 보완&quot;
# [그러면서 &quot;최근 BTS, <b>오징어게임</b> 등 우리의 문화·콘텐츠가 세계적으로 각광받으며 새로운 성장·수출동력으로 부상하고 있지만, 국내 서비스산업 생산성은 OECD(경제협력개발기구) 평균(88억5000 달러)의 70% 수준... ]
# 20 : 추경호 &quot;서비스산업 발전은 필수 새 성장 동력...입법 추진&quot;
# [추 부총리는 최근 BTS, <b>오징어게임</b> 등 우리의 다양한 문화·콘텐츠가 세계적으로 주목받으며 새로운 성장과 수출동력으로 부상하고 있지만, 국내 서비스산업 생산성은 OECD 평균의 70% 수준에 불과해 주요국 대비 크게 낮은... ]
# 21 : 추경호 &quot;서비스산업, 새 성장 동력…서비스발전법 추진&quot;
# [그는 “최근 BTS, <b>오징어게임</b> 등 우리의 다양한 문화콘텐츠가 세계적으로 각광받으며 새로운 성장 동력으로 부상하고 있다”며 “그러나 국내 서비스산업 생산성은 경제협력개발기구(OECD) 평균의 70%에 불과해 주요국... ]
# 22 : 추경호 &quot;성장 잠재력 제고 위해 서비스산업 혁신 박차&quot;
# [최근 BTS, <b>오징어게임</b> 등 우리의 다양한 문화·콘텐츠가 세계적으로 각광받으며 새로운 성장·수출동력으로 부상하고 있지만 국내 서비스산업 생산성은 경제협력개발기구(OECD) 평균의 70% 수준에 불과한 수준이다.... ]
# 23 : 秋부총리 &quot;서비스산업은 새 성장·수출동력…서비스발전법 입법&quot;
# [그는 &quot;최근 BTS, <b>오징어게임</b> 등 우리의 다양한 문화·콘텐츠가 세계적으로 각광받으며 새로운 성장·수출동력으로 부상하고 있다&quot;며 &quot;그러나 국내 서비스산업 생산성은 경제협력개발기구(OECD) 평균의 70% 수준에 불과해... ]
# 24 : 추경호 &quot;서비스산업 구조개혁 필요…내년 초 5개년 계획 발표&quot;
# [추 부총리는 &quot;서비스산업은 전체 고용의 70%, 부가가치의 60% 이상을 차지하는 우리 경제의 근간을 이루는 중추 산업으로 최근 BTS, <b>오징어게임</b> 등 다양한 문화·콘텐츠가 세계적으로 각광받으며 새로운 성장·수출동력으로... ]
# 25 : [종합] 추경호 부총리 &quot;서비스산업발전기본법 입법화...정책 수단 총동원&quot;
# [우선 추 부총리는 서비스산업 혁신 추진과 관련해 &quot;서비스산업은 전체 고용의 70%, 부가가치의 60% 이상을 차지하는 등 우리 경제의 근간을 이루고 있는 중추산업&quot;이라며 &quot;최근 BTS, <b>오징어게임</b> 등 우리의 다양한 문화... ]
# 26 : 추경호 &quot;서비스산업은 새 성장·수출동력…서비스발전법 입법&quot;
# [그는 &quot;최근 BTS, <b>오징어게임</b> 등 우리의 다양한 문화·콘텐츠가 세계적으로 각광받으며 새로운 성장·수출동력으로 부상하고 있다&quot;며 &quot;그러나 국내 서비스산업 생산성은 경제협력개발기구(OECD) 평균의 70% 수준에 불과해... ]
# 27 : 추경호 &quot;서비스산업발전TF 이달 구성…구조개혁 계획은 내년초&quot;
# [추 부총리는 &quot;최근 BTS, <b>오징어게임</b> 등 다양한 문화·콘텐츠가 세계적으로 각광받으며 새 성장·수출동력으로 부상하고 있으나 국내 서비스산업 생산성은 경제협력개발기구(OECD) 평균의 70% 수준에 불과하는 등 주요국 대비... ]
# 28 : &quot;대세는 OTT·메타버스·유튜버&quot;…3대 新성장엔진으로 &apos;30조 시장&apos; 만든다
# [OTT 글로벌 진출로 &apos;<b>오징어게임</b>&apos; 신화 잇는다…국내 OTT 세액공제도 추진 OTT 부문의 경우 넷플릭스의 &apos;<b>오징어게임</b>&apos;과 같이 비용 대비 높은 효과성과 창의성을 인정받은 한국 콘텐츠가 글로벌 OTT 플랫폼에서도 인기를 얻고... ]
# 29 : 최민식 X 손석구 X 이동휘 디즈니+ 오리지널 &lt;카지노&gt; 12월 공개
# [이와 함께 넷플릭스 &lt;<b>오징어 게임</b>&gt;의 허성태와 김주령을 비롯해 류현경, 조재윤, 진선규 등이 출연한다. 688만 관객을 동원한 &lt;범죄도시&gt;(2017)로 제54회 백상예술대상 신인감독상, 제23회 춘사영화제 신인감독상을 수상한... ]
# 30 : 피카소와 폴고갱이 함께... 제니안, 아트패션쇼 성황리 마쳐
# [특히 전 세계를 강타한 넷플릭스 드라마 &lt;<b>오징어 게임</b>&gt;으로 유명해진 동그라미세모네모(○△□)의 디자인 원천 특허를 보유중인 그다. 한편, 해당 행사는 디자이너 제니안을 필두로 전속모델 박노철, 최인하 외... ]
# 31 : [엔터Biz] 3Q 호실적 잔치에도 JYP SM &apos;웃고&apos; 하이브 YG &apos;울고&apos;
# [세계인의 환호를 이끌어 내고 있는 방탄소년단(BTS)이 한류 콘텐츠의 대표 아이콘으로 우뚝 선 가운데 봉준호 감독의 &apos;기생충&apos;, 넷플릭스 오리지널 시리즈 &apos;<b>오징어 게임</b>&apos; 등 국내 엔터테인먼트 업계의 신한류 콘텐츠가... ]
# 32 : &apos;다큐인사이트&apos; 살인의 추억부터 <b>오징어 게임</b>까지…K-무비의 시작은 2003년?
# [[기생충], [헤어질 결심], [<b>오징어 게임</b>] 등 지금 잘 나가는 한국 영화, K-콘텐츠를 바라보며 지속가능성에 대한 고민과 우려 속에서, 우리는 잠시 멈춰 오래된 일기장을 다시 들춰보는 기분으로 한국 영화의 &apos;화양연화... ]
# 33 : <b>오징어게임</b>과 컬래버한 아트토이···게이즈샵, &apos;베어브릭X스퀴드게임&apos; 론칭
# [스마트 라이프스타일 편집숍 게이즈샵(GAZESHOP)이 넷플릭스를 통해 방영한 대한민국 드라마 &apos;<b>오징어게임</b>&apos;과 컬래버한 &apos;베어브릭 X 스퀴드게임(BE@RBRICK X SQUIDGAME)&apos;을 출시했다고 17일 밝혔다.<b>오징어게임</b>은 &quot;무궁화 꽃이... ]
# 34 : &quot;체육공원 숙원… 비행기 소음 장기적 해결해야&quot;
# [박일순 남일면 주민자치위원장(48)은 &quot;남일면은 도심과 농촌이 공존하고 있으며 시골 인심이 살아있는 곳&quot;이라며 &quot;노인과 청년의 화합이 잘 이뤄지고 일례로 최근에 &apos;오영남(<b>오징어게임</b>+영화+남일면) 축제&apos;를 했는데... ]
# 35 : 낡은 규제 걷어내자 신산업 기술혁신 생태계 `온기`
# [◇고추장 등 우리 고유상품 명칭 &apos;해외 무단 선점&apos; 방지= BTS(방탄소년단), <b>오징어게임</b> 등 우수한 한류 콘텐츠의 폭발적인 인기에 힘입어 우리나라 식품, 의복 등에 대한 관심이 세계적으로 커지고 있다. 그런데 소주, 된장... ]
# 36 : &apos;다큐인사이트&apos; 한국영화 르네상스라 불리던 2003년의 모습은
# [&apos;기생충&apos;, &apos;헤어질 결심&apos;, &apos;<b>오징어 게임</b>&apos; 등 지금 잘 나가는 한국영화 K-콘텐츠를 바라보며 지속가능성에 대한 고민과 우려 속에서 우리는 잠시 멈춰 오래된 일기장을 다시 들춰보는 기분으로 한국영화의 &apos;화양연화... ]
# 37 : AI로 국악 보존·한옥서 공연
# [넷플릭스 드라마 <b>오징어 게임</b>은 신선하고 파격적인 신한류 열풍을 일으키며 에미상 6관왕에 오르는 기염을 토했다. 이러한 흐름에 발 맞춰 풍류를 사랑하고 문화예술을 애호했던 우리 전통문화예술의 가치를 세상에... ]
# 38 : [파워K-우먼]최크리 &quot;좋아하고, 잘하는 것에 새로운 것 융합해야&quot;
# [있고 <b>오징어게임</b> 사례에서도 나타나듯 콘텐츠에서도 두각을 나타내고 있어서 크리에이티브 테크라는 분야에서도 시너지를 내고 있어서 융합에 대한 기대감이 크다고 느낀다&quot;고 말했다. 투자 업무를 오랫동안 도맡았던 최... ]
# 39 : &apos;2022 한류생활문화한마당 모꼬지 대한민국&apos; 우즈벡‧말레이 한류팬과 함께 성...
# [&lt;<b>오징어 게임</b>&gt;의 인기로 한국 놀이 문화에 대한 관심도 컸다. &apos;무궁화 꽃이 피었습니다&apos;를 비롯해 윷놀이, 사방치기, 투호 등 다양한 전통 놀이를 적극적으로 즐기는 모습을 보였다. 잡채, 불고기, 식혜 등 다양한 한식... ]
# 40 : &apos;2022 한류생활문화한마당 모꼬지 대한민국&apos; 성료
# [&lt;<b>오징어 게임</b>&gt;의 인기로 한국 놀이 문화에 대한 관심도 컸다. &apos;무궁화 꽃이 피었습니다&apos;를 비롯해 윷놀이, 사방치기, 투호 등 다양한 전통 놀이를 적극적으로 즐기는 모습을 보였다. &apos;모꼬지 대한민국&apos;의 하이라이트는... ]
# 41 : 이 학생은 자라서 윤석열 정부의 실세 중 실세가 됩니다 (+정체)
# [그리고 &apos;<b>오징어 게임</b>&apos;으로 미국 에미상 시상식에서 남우주연상을 수상하고 스타워즈 시리즈 주연을 맡으며 최상의 커리어를 쌓고 있는 이정재 또한 한 장관의 현대고 동창이다. 현대고를 졸업한 한 장관은 서울대 법대... ]
# 42 : ‘2022 한류생활문화한마당 모꼬지 대한민국’ 성료
# [&lt;<b>오징어 게임</b>&gt;의 인기로 한국 놀이 문화에 대한 관심도 컸다. ‘무궁화 꽃이 피었습니다’를 비롯해 윷놀이, 사방치기, 투호 등 다양한 전통 놀이를 적극적으로 즐기는 모습을 보였다. 잡채, 불고기, 식혜 등 다양한 한식... ]
# 43 : ‘2022 한류생활문화한마당 모꼬지 대한민국’ 성료
# [&lt;<b>오징어 게임</b>&gt;의 인기로 한국 놀이 문화에 대한 관심도 컸다. 드라마에 등장하는 ‘무궁화꽃이 피었습니다’를 비롯해 윷놀이, 사방치기, 투호, 딱지치기 등 다양한 전통 놀이를 적극적으로 즐기는 모습을 보였다. 또한... ]
# 44 : [지스타 2022] &quot;오이소, 보이소&quot; 막 오른 K<b>게임</b> 신작 대전
# [&apos;<b>오징어게임</b>&apos; 트레이드마크인 초록색 트레이닝복을 입고 등장해 눈길을 끌었던 지난해와 달리 올해는 간소화 방식으로 진행된 점이 특징이다. 넥슨 자회사 네오플이 개발한 &apos;던전앤파이터 모바일(던파 모바일)&apos;은 지난... ]
# 45 : [인터뷰 | 지경화 한국콘텐츠진흥원 해외사업지원단 단장] &quot;해외시장 정보 기...
# [인도네시아 말레이시아 등 동남아시아 국가들의 경우 OTT 플랫폼을 통해 &apos;<b>오징어게임</b>&apos; 등 한국드라마와 예능프로그램이 큰 인기를 얻고 있다. 유아와 청소년 대상 애니메이션과 캐릭터 콘텐츠에 대한 관심도 크다. 유럽... ]
# 46 : [시연기] 데이브 더 다이버, 닌텐도 스위치 버전의 또다른 매력
# [녹차를 따르거나 와사비를 갈 때의 스틱 조작 등 <b>게임</b>에 정갈하게 녹아드는 조작감도 일품이다. 또 중요한 것이 있다. PC 버전에서 미처 넣지 못했던 스토리 컷신이 닌텐도 스위치 버전에 들어가 있다. 초반에 거대 <b>오징어</b>... ]
# 47 : [지스타]&quot;작아도 바닷속은 광활하네&quot;...&apos;데이브 더 다이버&apos; 스위치 체험기
# [또, 아기자기한 도트 그래픽 스타일과 달리 손맛이 느껴지는 물고기 포획과 거대 <b>오징어</b>와의 사투 등 액션 파트 역시 출중하다. PC에서 즐길 수 있던 &apos;데이브 더 다이버&apos;는 닌텐도의 휴대용 <b>게임</b>기 닌텐도 스위치로도... ]
# 48 : &apos;2022 한류생활문화한마당 모꼬지 대한민국&apos; 마무리...&quot;새로운 한류의 가능성...
# [&lt;<b>오징어 게임</b>&gt;의 인기로 한국 놀이 문화에 대한 관심도 컸다. 드라마에 등장하는 &apos;무궁화 꽃이 피었습니다&apos;를 비롯해 윷놀이, 사방치기, 투호, 딱지치기 등 다양한 전통 놀이를 적극적으로 즐기는 모습을 보였다. 또한... ]
# 49 : ‘2022 한류생활문화한마당 모꼬지 대한민국’ 성료... 우즈백‧말레이 한류팬...
# [&lt;<b>오징어 게임</b>&gt;의 인기로 한국 놀이 문화에 대한 관심도 컸다. ‘무궁화 꽃이 피었습니다’를 비롯해 윷놀이, 사방치기, 투호 등 다양한 전통 놀이를 적극적으로 즐기는 모습을 보였다. 잡채, 불고기, 식혜 등 다양한 한식... ]
# 50 : 피카소와 폴고갱이 함께한 제니안 &apos;아트패션쇼&apos; 성황리에 종료
# [특히 전 세계를 강타한 넷플릭스 드라마 &lt;<b>오징어 게임</b>&gt;으로 유명해진 동그라미세모네모(○△□)의 디자인 원천 특허를 제니안이 보유중이어서 화제다. 이번 워킹에 선보인 데님에 ○△□ 디자인을 독특하게 콜라주 형태로... ]
# 51 : &apos;2022 한류생활문화한마당 모꼬지 대한민국&apos; 성료.. 우즈벡‧ 말레이 5만여명...
# [&apos;<b>오징어 게임</b>&apos;의 인기로 한국 놀이 문화에 대한 관심도 컸다. 드라마에 등장하는 &apos;무궁화 꽃이 피었습니다&apos;를 비롯해 윷놀이, 사방치기, 투호, 딱지치기 등 다양한 전통 놀이를 적극적으로 즐기는 모습을 보였다. 잡채... ]
# 52 : 새로운 한류의 가능성이 열렸다! ‘2022 한류생활문화한마당 모꼬지 대한민국...
# [&lt;<b>오징어 게임</b>&gt;의 인기로 한국 놀이 문화에 대한 관심도 컸다. 드라마에 등장하는 ‘무궁화 꽃이 피었습니다’를 비롯해 윷놀이, 사방치기, 투호, 딱지치기 등 다양한 전통 놀이를 적극적으로 즐기는 모습을 보였다. 또한... ]
# 53 : 지금은 문화교류의 시대
# [그 방증으로 넷플릭스 오리지널의 &apos;<b>오징어 게임</b>&apos;은 미국 방송계에 최고 권위를 가지고 있는 &apos;에미상&apos; 시상식에서 비영어권 드라마로는 최초 감독상, 남우주연상을 거머쥐었고, 단일 드라마로서 6관왕을 차지했다. 한국... ]
# 54 : &apos;2022 한류생활문화한마당 모꼬지 대한민국&apos; 성료
# [&apos;<b>오징어 게임</b>&apos;의 인기로 한국 놀이 문화에 대한 관심도 컸다. 드라마에 등장하는 &apos;무궁화 꽃이 피었습니다&apos;를 비롯해 윷놀이, 사방치기, 투호, 딱지치기 등 다양한 전통 놀이를 적극적으로 즐기는 모습을 보였다. 또한... ]
# 55 : 우즈베키스탄, 말레이시아 5만명 한류 팬 운집한 까닭
# [&lt;<b>오징어 게임</b>&gt;에 등장하는 &apos;무궁화 꽃이 피었습니다&apos;를 비롯해 윷놀이, 사방치기, 투호, 딱지치기 등 다양한 전통 놀이를 즐겼다. 잡채, 불고기, 약과, 식혜 등 다양한 한식 시식회와 &apos;김장 체험&apos;, &apos;전 부치기&apos; 등 한식 조리... ]
# 56 : [더보기] 이정재 ‘헌트’부터 안태진 ‘올빼미’까지… 놓치면 아쉬울 올해의...
# [지난해 넷플릭스 시리즈 ‘<b>오징어 게임</b>’으로 글로벌 스타로 거듭난 배우 이정재의 감독 데뷔작인 ‘헌트’는 물론 오는 23일 개봉을 앞둔 안태진 감독의 ‘올빼미’까지. 데뷔작이라는 게 믿기지 않을 정도로 훌륭한... ]
# 57 : &apos;한류생활문화한마당 모꼬지 대한민국&apos; 성료…우즈벡·말레이에 5만3000명 운...
# [넷플릭스 오리지널 시리즈 &apos;<b>오징어 게임</b>&apos;의 인기로 한국 놀이 문화에 대한 관심도 컸다. 드라마에 등장하는 &apos;무궁화꽃이 피었습니다&apos;를 비롯해 윷놀이, 사방치기, 투호, 딱지치기 등 다양한 전통 놀이를 적극적으로 즐기는... ]
# 58 : 항만 안전 40년 발자취 담았다
# [배준영 국민의힘 의원은 “항만은 예선이 없으면 멈춰 버리기에 굉장히 중요한 산업”이라며 “골든글로브를 수상한 <b>오징어게임</b>의 오영수처럼 조연 같지만 주연 같은 예선의 41주년을 진심으로 축하한다”고 말했다.... ]
# 59 : 피카소·폴고갱 함께한 제니안 ‘아트패션쇼’ 성료
# [제니안은 특히 전 세계를 강타한 넷플릭스 드라마 ‘<b>오징어 게임</b>’으로 유명해진 동그라미세모네모(○△□)의 디자인 원천 특허를 보유중이다. 그는 이번 워킹에 선보인 데님에 ○△□ 디자인을 독특하게 콜라주 형태로... ]
# 60 : 카이·에일리 출동하니 우즈벡·말레이 들썩…5만3000명 운집
# [&apos;<b>오징어 게임</b>&apos;의 인기로 한국 놀이 문화에 대한 관심도 컸다. 현지인들은 드라마에 등장하는 &apos;무궁화 꽃이 피었습니다&apos;를 비롯해 윷놀이, 사방치기, 투호, 딱지치기 등 다양한 전통 놀이를 적극적으로 즐겼다.... ]
# 61 : &quot;몰랐는데 대세입니다&quot;…영화를 빨기감기로 보는 사람들 [신간]
# [8시간짜리 &apos;<b>오징어 게임</b>&apos;을 30분 만에 몰아보는 현상이 뉴스에 나오기도 하고, 고전을 10분 만에 요약해주는 영상이 인기를 끈다. &apos;빨리 감기&apos;로 대표되는 &apos;콘텐츠 소비 문화&apos;는 앞으로 더욱 가속화될 수밖에 없다. 저자는... ]
# 62 : 디즈니 플러스 오리지널 ‘카지노’ 12월 21일 공개 확정…최민식·손석구·이...
# [등에서 독보적인 존재감을 과시한 배우 이동휘가 합류한다. 또 최근 ‘괴물’과 ‘<b>오징어 게임</b>’에서 남다른 임팩트를 선사한 배우 허성태가 출연해 개성 넘치는 배우들이 빚어낼 최고의 앙상블을 기대하게 한다. NSP통신]
# 63 : [대회] 2022 한조 팁런 마스터즈 결승_198마리 난타전 끝에 장원삼 선수 챔피...
# [이 대회를 통해 무늬<b>오징어</b> 팁런 낚시가 묘미 넘치는 <b>게임</b>피싱 장르로 발전하기를 기원합니다”라며 기획 취지를 설명했다. 한조팁런마스터즈는 내년 가을에 2023년 대회가 열리며 1회 대회의 뜨거웠던 반응에... ]
# 64 : 새로운 한류의 가능성이 열렸다! ‘2022 한류생활문화한마당 모꼬지 대한민국...
# [&lt;<b>오징어 게임</b>&gt;의 인기로 한국 놀이 문화에 대한 관심도 컸다. 드라마에 등장하는 ‘무궁화 꽃이 피었습니다’를 비롯해 윷놀이, 사방치기, 투호, 딱지치기 등 다양한 전통 놀이를 적극적으로 즐기는 모습을 보였다. 또한... ]
# 65 : 에어비앤비 창업자 &quot;韓숙소 검색 590% 늘어…한옥을 카테고리로&quot;
# [그는 &quot;BTS, 기생충, <b>오징어게임</b> 등 한국 대중문화에 대한 관심이 높아지고 있다&quot;며 &quot;올해 3분기 에어비앤비에서 외국인의 한국 숙소 검색량은 지난해 동기보다 590% 증가했다&quot;고 말했다. 네이선 CSO는 최근 높아지는 규제... ]
# 66 : 성수·한남 앞으로도 핫할까…상업용 부동산 전문가의 전망은
# [‘수리남’ ‘<b>오징어게임</b>’처럼 1~3회를 시리즈로 공개하며 새로운 경험을 줘요. 브랜드의 넥스트 스텝이 궁금해지도록요. 어떤 매장이 오픈하는가에 따라 거리의 모습도 바뀌겠죠? 최근에는 건물 자체가 하나의 거리로... ]
# 67 : MAMA의 새로운 도전 “월드 넘버원 K팝 어워즈” (2022 MAMA AWARDS 글로벌 기...
# [바로 ‘기생충’과 ‘<b>오징어 게임</b>’의 음악감독인 정재일과 대한민국의 레전드 래퍼 타이거 JK, 그리고 Stray Kids의 자체 프로듀싱 팀 ‘3RACHA (방찬, 창빈, 한)’가 한 무대에 오르는 것. 이들이 전 세계에... ]
# 68 : 세계 유력 인사들 한국영화 주목하고 있다
# [찰스 리브킨 회장은 &quot;지금은 영화 &apos;기생충&apos; &apos;미나리&apos; &apos;헌트&apos;를 비롯해 &apos;<b>오징어 게임</b>&apos; &apos;이상한 변호사 우영우&apos;, 여기에 BTS, 블랙핑크에 이르기까지 한국 문화가 그 어느 때보다도 더 많이 세계인과 만나고 있는 특별한 순간... ]
# 69 : 최민식-손석구-이동휘의 카리스마 &apos;카지노&apos;, 디즈니플러스 12월 공개
# [또한 최근 [괴물]과 [<b>오징어 게임</b>]에서 남다른 임팩트를 선사한 배우 허성태가 출연해 개성 넘치는 배우들이 빚어낼 최고의 앙상블을 기대하게 한다. 또한 &lt;카지노&gt;는 화끈한 액션과 속도감 있는 전개를 담아내며 688만... ]
# 70 : “‘스타워즈’=미국의 자존심”…이정재의 시리즈 합류가 증명한 것
# [‘<b>오징어게임</b>’으로 글로벌 스타덤에 오른 뒤 본격적인 해외무대에 나서게 됐다. 특히 국내에서는 유난히 흥행 성적이 저조했던 영화 ‘스타워즈’ 시리즈의 새로운 드라마를 책임지게 되면서 기대 섞인 시선을 모은다.... ]
# 71 : [투데이 窓]압사참사 이후 K컬처 팬들의 미래
# [넷플릭스 드라마 &apos;<b>오징어게임</b>&apos;도 마찬가지다. 빚에 쪼들리고 생명의 위협까지 당하는 금융현실을 적나라하게 보여줬다. 이 또한 한국에만 해당하는 것이 아니므로 전세계인의 공감을 얻었다. 영화와 드라마만이 아니다.... ]
# 72 : “‘마마 어워즈’, 아시아 넘어 월드 넘버원으로…K팝의 새로운 미래 제시할...
# [영화 ‘기생충’과 넷플릭스 드라마 ‘<b>오징어 게임</b>’의 음악감독인 정재일과 래퍼 타이거 JK, K팝 그룹스트레이키즈(Stray Kids)의 자체 프로듀싱 팀 ‘쓰리라차(3RACHA, 방찬, 창빈, 한)’도 한 무대를 선다. ‘마마... ]
# 73 : 2002 축구 국가대표 아버지(김현수)와 2022 미스코리아 딸(김고은)
# [제가 언니가 아니라 이모 같아요.(ㅎㅎㅎ).&quot; 주변에서 &apos;사진찍자&apos;, &apos;사인해달라&apos; 등 이제야 미스코리아 미가 된 것을 실감하고 있는 김 씨는 &quot;&apos;<b>오징어 게임</b>&apos;에 출연해 세계적인 인지도를 자랑하는 모델 출신 배우 정호연처럼... ]
# 74 : 안철수, 인신협 정책 포럼에서 &quot;초격차 기술 확보해야 우리나라 생존가능&quot;
# [이어 컨텐츠 분야에 대해 “<b>오징어 게임</b>부터 아카데미 상을 받은 미나리 등 우리나라가 얼마나 이쪽에 가능성이 많냐”며 “우리나라 정도면 삼성전자급 규모의 콘텐츠 대기업을 만들 수 있다”고 전망했다. 그러면서... ]
# 75 : [기고]창작자 &apos;정당한 보상청구권&apos; 도입 신중해야
# [창작자가 흥행 실적에 상응하는 수익을 분배받지 못한 사례로 &apos;<b>오징어 게임</b>&apos;이 제시된다. &apos;<b>오징어 게임</b>&apos;은 시나리오 완성 이후 세상에 나와 빛을 보게 되기까지 10년이 걸린 작품임을 기억하거나 주목하는 사람은 드물다.... ]
# 76 : &apos;2022 MAMA AWARDS&apos; 호스트 박보검·전소미, 방탄소년단 제이홉 솔로 무대 공...
# [바로 &apos;기생충&apos;과 &apos;<b>오징어 게임</b>&apos;의 음악감독인 정재일과 대한민국의 레전드 래퍼 타이거 JK, 그리고 Stray Kids의 자체 프로듀싱 팀 &apos;3RACHA (방찬, 창빈, 한)&apos;가 한 무대에 오르는 것. 이들이 전 세계에... ]
# 77 : 제이홉 솔로에 아이브x뉴진스 콜라보까지..박보검의 &apos;MAMA&apos; 커밍순
# [바로 ‘기생충’과 ‘<b>오징어 게임</b>’의 음악감독인 정재일과 대한민국의 레전드 래퍼 타이거 JK, 그리고 Stray Kids의 자체 프로듀싱 팀 ‘3RACHA (방찬, 창빈, 한)’가 한 무대에 오르는 것. 이들이 전... ]
# 78 : 2.6조원 수출효자 `<b>게임</b>`… 북미·유럽 잭팟 노린다
# [&apos;BTS&apos;, &apos;기생충&apos;, &apos;<b>오징어게임</b>&apos; 등 한국 콘텐츠의 잇따른 세계적인 흥행으로, 북미·유럽 시장에서도 한국 게임이 좋은 반응을 얻고 있다. 넷마블, 엔씨소프트, 크래프톤, 컴투스, 펄어비스 등 게임 5개 상장사의 올해... ]
# 79 : &apos;탄생&apos; 최정상급 제작진 참여
# [시각효과에 참여한 웨스트월드는 ‘<b>오징어 게임</b>’, ‘닥터브레인’, ‘스위트홈’, 영화 ‘서복’ 등 세계적인 수준의 실력을 ‘탄생’에서도 역시 박수를 자아낼 것이다. 명배우진으로 기대감을 모으고 있는 영화... ]
# 80 : 최민식·손석구·이동휘 최후의 베팅…&apos;카지노&apos;, 12월 21일 공개 [공식]
# [또한 최근 ‘괴물’과 ‘<b>오징어 게임</b>’에서 남다른 임팩트를 선사한 배우 허성태가 출연해 개성 넘치는 배우들이 빚어낼 최고의 앙상블을 기대하게 한다. 디즈니+ 오리지널 시리즈 ‘카지노’는 12월 21일(수) 오직 디즈니... ]
# 81 : 한류 스타는 부재중... 김태호·나영석이 해외로 눈 돌린 이유
# [&apos;<b>오징어 게임</b>&apos;으로 세계를 홀린 이정재는 요즘 영국 버크셔주 소재 스튜디오 등에서 &apos;스타워즈&apos; 새 시리즈 &apos;디 애콜라이트&apos;를 찍고 있다. 소속사 아티스트컴퍼니 관계자는 16일 &quot;이정재가 지난달 영국으로 출국했다&quot;며... ]
# 82 : &apos;오겜&apos; 줄다리기, 대표적 무형유산이지요
# [이경훈 국립무형유산원장 정부가 세운 세계 최초 무형유산 전승·보호 기구 일상 체험통한 전승에 주력 막걸리 빚기, 떡 만들기 등 전통기술·생활관습도 포함 전 세계적인 인기를 얻은 넷플릭스 시리즈 &apos;<b>오징어게임</b>&apos;은... ]
# 83 : 구독자를 가장 많이 보유한 개인 유튜버는?
# [지난해 그는 현실판 &lt;<b>오징어 게임</b>&gt; 콘텐츠로 화제를 모았고, 덕분에 전 세계에서 가장 많은 돈을 번 유튜버로 기록되기도 했죠. 그는 최근 몇 년 동안 급격하게 구독자를 늘리면서 1위 자리를 노렸습니다. 그의 팬들은... ]
# 84 : 국내 대기업의 사회공헌프로그램 | “기업의 사회적 책임을 넘어, 다 같이 행...
# [넷플릭스에서 방영된 〈<b>오징어 게임</b>〉의 황동혁 감독, 주연배우 이정재가 에미상을 받으며 K 콘텐츠의 저력을 전 세계에 알렸다. K 팝의 성공 배경에는 다양한 이유가 있지만 ‘K-콘텐츠 산업’이 지속 성장하기... ]
# 85 : 인생의 끝에서 목숨을 건 최후의 베팅을 시작한 최민식, 손석구, 이동휘
# [그리고 최근 [괴물]과 [<b>오징어 게임</b>]에서 남다른 임팩트를 선사한 배우 허성태가 출연해 개성 넘치는 배우들이 빚어낼 최고의 앙상블을 기대하게 한다. 또한 &lt;카지노&gt;는 화끈한 액션과 속도감 있는 전개를 담아내며 688만... ]
# 86 : ‘2022 MAMA AWARDS’, 박보검·전소미 호스트 발탁..“K-POP 새로운 미래 제...
# [바로 ‘기생충’과 ‘<b>오징어 게임</b>’의 음악감독인 정재일과 대한민국의 레전드 래퍼 타이거 JK, 그리고 Stray Kids의 자체 프로듀싱 팀 ‘3RACHA (방찬, 창빈, 한)’가 한... ]
# 87 : 마마, 아시아 떼어 버린 이유…방탄소년단 제이홉 출연
# [이와 함께 영화 &apos;기생충&apos;과 넷플릭스 시리즈 &apos;<b>오징어게임</b>&apos;의 음악감독이자 전방위 뮤지션으로 통하는 정재일, 래퍼 타이거JK, &apos;빌보드 200&apos; 2차례 1위에 빛나는 4세대 간판 보이그룹 &apos;스트레이키즈&apos;의 자체 프로듀싱팀... ]
# 88 : 디즈니+ ‘카지노’, 12월 21일 공개 확정..최민식·손석구·이동휘 캐릭터 포...
# [또한 최근 [괴물]과 [<b>오징어 게임</b>]에서 남다른 임팩트를 선사한 배우 허성태가 출연해 개성 넘치는 배우들이 빚어낼 최고의 앙상블을 기대하게 한다. 또한 &lt;카지노&gt;는... ]
# 89 : ‘MAMA 어워즈’ 오사카서 이틀간 개최…제이홉 솔로무대 최초 공개
# [케플러의 총 다섯 개 그룹 32명이 이 한 무대에 오른다. 영화 ‘기생충’과 넷플릭스 시리즈 ‘<b>오징어게임</b>’의 음악감독 정재일과 래퍼 타이거JK, 보이그룹 스트레이키즈의 방찬, 창빈, 한도 협업 무대를 꾸민다.]
# 90 : 최민식 25년 만의 스크린 밖 도전…디즈니+ ‘카지노’ 공개 날짜 확정
# [또한 최근 ‘괴물’ ‘<b>오징어 게임</b>’에서 남다른 임팩트를 선사한 허성태가 출연해 개성 넘치는 배우들이 빚어낼 최고의 앙상블을 기대하게 한다. 디즈니+의 오리지널 시리즈 ‘카지노’는 다음 달 21일 오직 디즈니+를... ]
# 91 : 최민식·손석구·이동휘 ‘카지노’, 12월 21일 공개
# [또한 최근 ‘괴물’과 ‘<b>오징어 게임</b>’에서 남다른 임팩트를 선사한 배우 허성태가 출연해 개성 넘치는 배우들이 빚어낼 최고의 앙상블을 기대하게 한다. 또한 ‘카지노’는 화끈한 액션과 속도감 있는 전개를 담아내며... ]
# 92 : 국민의힘에 보수의 가치와 품격이 있는가 [소셜 코리아]
# [정당 변해야 <b>오징어 게임</b> 벗어나… 비겁하고 쉬운 &apos;진보 탓&apos; 이제 그만 한국의 공론장은 다이내믹합니다. 매체도 많고, 의제도 다양하며 논의가 이뤄지는 속도도 빠릅니다. 하지만 많은 논의가 대안 모색 없이 종결됩니다.... ]
# 93 : 최민식·손석구·이동휘, 목숨 건 베팅…&apos;카지노&apos; 포스터 공개
# [또 최근 &apos;괴물&apos;과 &apos;<b>오징어 게임</b>&apos;에서 남다른 임팩트를 선사한 배우 허성태가 출연해 개성 넘치는 배우들이 빚어낼 최고의 앙상블을 기대하게 한다. 또한 &apos;카지노&apos;는 화끈한 액션과 속도감 있는 전개를 담아내며 688만 관객을... ]
# 94 : &apos;범죄도시&apos; 마동석 오른팔이었던 남배우, 음주운전 후 2년 만에 복귀
# [홍기준의 혈줄알코올농도는 면허 취소 수준이었다.결국 홍기준은 출연 예정이었던 넷플릭스 &apos;<b>오징어게임</b>&apos;에서도 물러났다. 그가 캐스팅됐던 조직폭력배 장덕수 역은 허성태에게 돌아갔다. 자숙에 들어간 홍기준은... ]
# 95 : ‘카지노’, 내달 21일 공개 확정…‘숨멎’ 최민식X손석구X이동휘 캐릭터 포...
# [또한 최근 ‘괴물’과 ‘<b>오징어 게임</b>’에서 남다른 임팩트를 선사한 배우 허성태가 출연해 개성 넘치는 배우들이 빚어낼 최고의 앙상블을 기대하게 한다. 또한 ‘카지노’는 화끈한 액션과 속도감 있는 전개를 담아내며... ]
# 96 : [현장EN:]12년 유지한 MAMA, &apos;마마 어워즈&apos; 된 이유
# [&apos;기생충&apos;과 &apos;<b>오징어 게임</b>&apos; 음악을 담당한 정재일 음악감독, 래퍼 타이거 JK, 스트레이 키즈의 프로듀싱 팀 쓰리라차 방탄, 창빈, 한이 함께하는 무대는 장르와 세대를 넘나든다는 점에서 기대를 모은다. 올해는 해외... ]
# 97 : 최민식X손석구X이동휘 ‘카지노’, 12월 21일 공개 확정…캐릭터 포스터 오픈
# [또한 최근 ‘괴물’과 ‘<b>오징어 게임</b>’에서 남다른 임팩트를 선사한 배우 허성태가 출연해 개성 넘치는 배우들이 빚어낼 최고의 앙상블을 기대하게 한다. 또한 ‘카지노’는 화끈한 액션과 속도감 있는 전개를 담아내며... ]
# 98 : 최민식·손석구·이동휘 &apos;카지노&apos;, 내달 21일 디즈니+ 공개
# [&apos;카지노&apos;에는 최근 &apos;괴물&apos;과 &apos;<b>오징어 게임</b>&apos;에서 남다른 임팩트를 선사한 배우 허성태가 출연하며 개성 넘치는 배우들이 빚어낼 앙상블을 기대케 한다. 디즈니+의 &apos;카지노&apos;는 내달 21일 전 세계에 공개된다.]
# 99 : 최민식X손석구X이동휘 &apos;카지노&apos;, 12월 21일 디즈니+ 공개
# [또한 최근 &apos;괴물&apos;과 &apos;<b>오징어 게임</b>&apos;에서 남다른 임팩트를 선사한 허성태가 출연해 개성 넘치는 배우들이 빚어낼 최고의 앙상블을 예고했다. 제54회 백상예술대상 신인감독상, 제23회 춘사영화제 신인감독상 수상에 빛나는... ]
# 100 : 최민식X손석구 &apos;카지노&apos;, 12월 21일 디즈니+ 공개 확정
# [또한 최근 &apos;괴물&apos;과 &apos;<b>오징어 게임</b>&apos;에서 남다른 임팩트를 선사한 배우 허성태도 출연해 존재감을 과시할 예정이다. 연출은 영화 &apos;범죄도시&apos;로 688만 흥행에 성공한 바 있는 강윤성 감독이 맡았다.]

# %% [markdown]
# ## 이상 정적 데이터 수집 방법
